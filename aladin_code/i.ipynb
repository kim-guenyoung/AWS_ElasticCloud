# %%
import pandas as pd

# %%
a = pd.read_csv('jinseok.csv', encoding= 'cp949')
b = pd.read_csv('jinseok1.csv', encoding= 'cp949')

# %%
a
# Out:
#     rank                                title   writer    price
# 0      1                  입이 트이는 영어 2023년 2월호     동아출판   8,800원
# 1      2  만일 내가 인생을 다시 산다면 (10만 부 기념 스페셜 에디션)      김혜남  12,000원
# 2      3                  귀가 트이는 영어 2023년 2월호     동아출판   8,800원
# 3      4              POWER ENGLISH 2023년 2월호     동아출판   6,400원
# 4      5                               사랑의 이해      이혁진  10,500원
# ..   ...                                  ...      ...      ...
# 75    76                                   불안  알랭 드 보통  10,500원
# 76    77                         사랑의 기술 (개정판)   에리히 프롬   8,400원
# 77    78                                  클루지   개리 마커스   9,660원
# 78    79                                종의 기원      정유정   9,100원
# 79    80                       2023 대한민국 산업지도      이래학  15,400원
#
# [80 rows x 4 columns]

# %%
b
# Out:
#     rank                                            title            writer  \
# 0      1                         그릿(50만부 판매 기념 리커버 골드에디션)          앤절라 더크워스
# 1      2                                       구의 증명 [할인]               최진영
# 2      3                                     트렌드 코리아 2023               김난도
# 3      4       맥심 MAXIM 2023. 1월호 (Friends with Benefits)             맥심편집부
# 4      5                         나의 월급 독립 프로젝트 (리마스터 에디션)               유목민
# 5      6                                       장단기 투자의 비밀           래리 윌리엄스
# 6      7                                        불편한 편의점 2               김호연
# 7      8                                           홍학의 자리               정해연
# 8      9                          맥심 MAXIM 2023. 2월호 (꽐라)             맥심편집부
# 9     10                                              역행자                자청
# 10    11                                 중급 중국어 2023년 2월호              동아출판
# ...

# %%
k = pd.concat([a,b],ignore_index= True)
k
# Out:
#     rank                                            title            writer  \
# 0      1                              입이 트이는 영어 2023년 2월호              동아출판
# 1      2              만일 내가 인생을 다시 산다면 (10만 부 기념 스페셜 에디션)               김혜남
# 2      3                              귀가 트이는 영어 2023년 2월호              동아출판
# 3      4                          POWER ENGLISH 2023년 2월호              동아출판
# 4      5                                           사랑의 이해               이혁진
# ..   ...                                              ...               ...
# 95    16                                         공정하다는 착각            마이클 샌델
# 96    17                                            돈의 속성               김승호
# 97    18  부자 아빠 가난한 아빠 20주년 특별 기념판 [부자 아빠 가난한 아빠 1 개정증보판]          로버트 기요사키
# 98    19                                         데일리 필로소피          라이언 홀리데이
# 99    20                                           돈의 심리학  모건 하우절 저 / 이지연 역
#
#       price
# 0    8,800원
# 1   12,000원
# 2    8,800원
# ...

# %%
k['rank'] = k.index+1
k
# Out:
#     rank                                            title            writer  \
# 0      1                              입이 트이는 영어 2023년 2월호              동아출판
# 1      2              만일 내가 인생을 다시 산다면 (10만 부 기념 스페셜 에디션)               김혜남
# 2      3                              귀가 트이는 영어 2023년 2월호              동아출판
# 3      4                          POWER ENGLISH 2023년 2월호              동아출판
# 4      5                                           사랑의 이해               이혁진
# ..   ...                                              ...               ...
# 95    96                                         공정하다는 착각            마이클 샌델
# 96    97                                            돈의 속성               김승호
# 97    98  부자 아빠 가난한 아빠 20주년 특별 기념판 [부자 아빠 가난한 아빠 1 개정증보판]          로버트 기요사키
# 98    99                                         데일리 필로소피          라이언 홀리데이
# 99   100                                           돈의 심리학  모건 하우절 저 / 이지연 역
#
#       price
# 0    8,800원
# 1   12,000원
# 2    8,800원
# ...

# %%
k.to_csv('yes24ebook.csv',encoding = 'cp949', index= False)
