# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
category_num = {
                "로맨스":"017001046",
                "BL": "017001064",
                "만화":"017001038",
                "판타지 무협": "017001049",
                "소설": "017001045",
                "경제 경영" : "017001047",
                "라이트노벨" : "01700106",
                "에세이 시" : "017001050",
                "인문" : "017001048",
                "사회 정치" : "017001051",
                "자기계발" : "017001054",
                "역사" : "017001052",
                "종교" : "017001053",
                "예술 대중문화" : "017001056",
                "자연과학" : "017001055",
                "가정 살림" : "017001042",
                "건강 취미 여행" : "017001043",
                "어린이 유아" : "017001058",
                "청소년" : "017001059",
                "국어 외국어" : "017001060",
                "IT 모발일" : "017001040",
                "대학교재" : "017001041",
                "수험서 자격증" : "017001061",
                "잡지" : "017001036",
                "해외원서": "017001032",
                "오디오북": "017001032",
                "크레마 (전자책 단말기)": "017001032"
                
}

# %%
name_mapping = {
                "로맨스":"문학",
                "BL": "문학",
                "만화":"문학",
                "판타지 무협": "문학",
                "소설": "문학",
                "경제 경영" : "경제/비즈니스",
                "라이트노벨" : "문학",
                "에세이 시" : "에세이/산문",
                "인문" : "인문",
                "사회 정치" : "인문",
                "자기계발" : "인문",
                "역사" : "인문",
                "종교" : "인문",
                "예술 대중문화" : "가정/생활",
                "자연과학" : "자연/과학",
                "가정 살림" : "가정/생활",
                "건강 취미 여행" : "가정/생활",
                "어린이 유아" : "가정/생활",
                "청소년" : "가정/생활",
                "국어 외국어" : "외국어",
                "IT 모발일" : "컴퓨터/인터넷",
                "대학교재" : "강의지원도서",
                "수험서 자격증" : "강의지원도서",
                "잡지" : "국외 eBook",
                "해외원서": "국외 eBook",
                "오디오북": "국외 eBook",
                "크레마 (전자책 단말기)": "국외 eBook"
                
}

# %%
def create_url(category_number):
    url = "http://www.yes24.com/24/category/bestseller?CategoryNumber={0}&sumgb=07&FetchSize=80".format(category_number)

    return url

# %%
def create_url2(category_number):
    url = "http://www.yes24.com/24/category/bestseller?CategoryNumber={0}&sumgb=07&FetchSize=20&PageNumber=2".format(category_number)

    return url

# %%
bookss = []
for key, value in category_num.items():
    rank = 0
    crolling_url = create_url(value)
    html = requests.get(crolling_url).text
    soup = BeautifulSoup(html, 'html.parser')#dd
    books = soup.select('td.goodsTxtInfo')
    
    
    

    for book in books:
        title = book.select('p:nth-child(1)')[0].text
        price = book.select('p:nth-child(3) > span.priceB')[0].text
        info = book.select('div.aupu')[0].text
        
        writer = info.split('|')[0]

        publisher = info.split('|')[1]

        date = info.split('|')[2]

        stars = book.select('p.review > img')
        
        star_content = 0
        star_edit = 0

        if stars==None:
                    
                star_content = 0
                star_edit = 0
                
        else:

        
            for star in stars[:5]:
                
                if star['src'] == 'http://image.yes24.com/sysimage/interface/StarOn.gif':
                    
                    star_content += 1

            for star in stars[5:]:

                if star['src'] == 'http://image.yes24.com/sysimage/interface/StarOn.gif':
        
                    star_edit += 1
        

        #print(key,title, writer, publisher, date, star_content,star_edit)
        rank +=1
        bookss.append([rank,title,writer, publisher, date,price, star_content,star_edit,key]) # 80 add

    crolling_url2 = create_url2(value)
    html2 = requests.get(crolling_url2).text
    soup2 = BeautifulSoup(html2, 'html.parser')
    books2 = soup2.select('td.goodsTxtInfo')

        
    for book in books2:
        title = book.select('p:nth-child(1)')[0].text
        price = book.select('p:nth-child(3) > span.priceB')[0].text
        info = book.select('div.aupu')[0].text
        
        writer = info.split('|')[0]

        publisher = info.split('|')[1]

        date = info.split('|')[2]

        stars = book.select('p.review > img')
        
        star_content = 0
        star_edit = 0

        if stars==None:
                    
                star_content = 0
                star_edit = 0
                
        else:

        
            for star in stars[:5]:
                
                if star['src'] == 'http://image.yes24.com/sysimage/interface/StarOn.gif':
                    
                    star_content += 1

            for star in stars[5:]:

                if star['src'] == 'http://image.yes24.com/sysimage/interface/StarOn.gif':
        
                    star_edit += 1
        

        #print(key,title, writer, publisher, date, star_content,star_edit)
        rank +=1
        
        bookss.append([rank,title,writer, publisher, date,price, star_content,star_edit,key]) # 20 add

# %%
df = pd.DataFrame(bookss, columns=['yes24_rank','title','yes24_writer', 'yes24_company','yes24_date','yes24_price' ,'yes24_star_content','yes24_star_edit','yes24_gener'])

df['yes24_date'] = df['yes24_date'].str.replace(pat=r'[^A-Za-z0-9가-힣]', repl=r' ', regex=True)

df['yes24_writer']=df['yes24_writer'].str.replace(pat=r'[^A-Za-z0-9가-힣]', repl=r' ', regex=True)
df['title'] = df['title'].str.replace(pat=r'[^A-Za-z0-9가-힣]', repl=r' ', regex=True)
for i in ['eBook','EPUB','완결','COMIC','PDF']:
    df['title'] = df['title'].str.replace(pat=i, repl=r' ', regex=True)


df['yes24_company'] = df['yes24_company'].str.replace(pat=r'[^A-Za-z0-9가-힣]', repl=r' ', regex=True)


func = lambda x: name_mapping.get(x, x)


df['sm_gener'] = df.yes24_gener.map(func)

df = df[['yes24_rank','title','yes24_writer', 'yes24_company','yes24_date','yes24_price' ,'yes24_star_content','yes24_star_edit','yes24_gener','sm_gener']]

df.to_csv('csv_file\yes24_gener.csv', index= False, encoding= 'utf-8')

# %%
c=pd.read_csv('csv_file\yes24_gener.csv',encoding = 'utf-8')
c
# Out:
#       yes24_rank                                              title  \
# 0              1             영주의 마녀
# 1              2        조건  만남  삽화본                             ...
# 2              3                      세트  오빠 손은 약손  외전 포함   총2권
# 3              4           토굴 공주
# 4              5                몸태질
# ...          ...                                                ...
# 2056          15        The Chalk Box Kid                       ...
# 2057          16        After the Music Stopped                 ...
# 2058          17        In an Unspoken Voice                    ...
# 2059          18        The Man Who Planted Trees               ...
# 2060          19        Play Your Bigger Game                   ...
#
#                                            yes24_writer  \
# 0      글로피 저                                        ...
# 1      문정민 저                                        ...
# 2      금나래 저                                        ...
# 3      함초롱 저                                        ...
# 4      금단 저                                         ...
# ...                                                 ...
# 2056   Clyde Robert Bulla 저                         ...
# 2057   Alan S  Blinder 저                            ...
# 2058   Peter A  Levine Ph D  저                      ...
# 2059   Jim Robbins 저                                ...
# 2060   Rick Tamlyn 저                                ...
#
#                                           yes24_company  \
# 0         고렘팩토리
# 1            로아
# 2            텐북
# 3          제로노블
# 4           라떼북
# ...                                                 ...
# 2056   Random House Children s Books                ...
# 2057   Penguin Publishing Group                     ...
# 2058   North Atlantic Books                         ...
# 2059   Random House Publishing Group                ...
# 2060   Hay House                                    ...
#
#                                        yes24_date yes24_price  \
# 0      2023년 01월                                       4,000원
# 1      2021년 05월                                       3,000원
# 2      2021년 05월                                       4,200원
# 3      2022년 12월                                       3,800원
# 4      2023년 02월                                       3,240원
# ...                                           ...         ...
# 2056   2015년 06월                                       7,000원
# 2057   2013년 01월                                      23,000원
# 2058   2012년 10월                                      29,000원
# 2059   2012년 04월                                      25,000원
# 2060   2013년 10월                                      20,500원
#
#       yes24_star_content  yes24_star_edit    yes24_gener  sm_gener
# 0                      4                4            로맨스        문학
# 1                      4                4            로맨스        문학
# 2                      4                4            로맨스        문학
# 3                      4                4            로맨스        문학
# 4                      3                3            로맨스        문학
# ...                  ...              ...            ...       ...
# 2056                   0                0  크레마 (전자책 단말기)  국외 eBook
# 2057                   0                0  크레마 (전자책 단말기)  국외 eBook
# 2058                   0                0  크레마 (전자책 단말기)  국외 eBook
# 2059                   0                0  크레마 (전자책 단말기)  국외 eBook
# 2060                   0                0  크레마 (전자책 단말기)  국외 eBook
#
# [2061 rows x 10 columns]
