# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from elasticsearch import Elasticsearch, helpers
import configparser
from datetime import datetime
import json

# %%
config = configparser.ConfigParser()
config.read('example.ini')
# Out:
# ['example.ini']

# %%
es = Elasticsearch(
    cloud_id=config['ELASTIC']['cloud_id'],
    http_auth=(config['ELASTIC']['user'], config['ELASTIC']['password'])
)
# Out:
# C:\Users\rlawl\AppData\Local\Temp\ipykernel_120648\2962435662.py:1: DeprecationWarning: The 'http_auth' parameter is deprecated. Use 'basic_auth' or 'bearer_auth' parameters instead
#   es = Elasticsearch(

# %%
category_num = {
                "로맨스":"017001046",
                "BL": "017001064",
                "만화":"017001038",
                "판타지 무협": "017001049",
                "소설": "017001045",
                "경제 경영" : "017001047",                  
                "라이트노벨" : "017001063",
                "에세이 시" : "017001050",
                "인문" : "017001048",
                "사회 정치" : "017001051",
                "자기계발" : "017001054",
                "역사" : "017001052",
                "종교" : "017001053",
                "예술 대중문화" : "017001056",
                "자연과학" : "017001055",
                "가정 살림" : "017001042",
                "건강 취미 여행" : "017001043",
                "어린이 유아" : "017001058",
                "청소년" : "017001059",
                "국어 외국어" : "017001060",
                "IT 모발일" : "017001040",
                "대학교재" : "017001041",
                "수험서 자격증" : "017001061",
                "잡지" : "017001036",
                "해외원서": "017001032",
                "오디오북": "017001032",
                "크레마 (전자책 단말기)": "017001032"
                
}

# %%
name_mapping = {
                "로맨스":"문학",
                "BL": "문학",
                "만화":"문학",
                "판타지 무협": "문학",
                "소설": "문학",
                "경제 경영" : "경제/비즈니스",
                "라이트노벨" : "문학",
                "에세이 시" : "에세이/산문",
                "인문" : "인문",
                "사회 정치" : "인문",
                "자기계발" : "인문",
                "역사" : "인문",
                "종교" : "인문",
                "예술 대중문화" : "가정/생활",
                "자연과학" : "자연/과학",
                "가정 살림" : "가정/생활",
                "건강 취미 여행" : "가정/생활",
                "어린이 유아" : "가정/생활",
                "청소년" : "가정/생활",
                "국어 외국어" : "외국어",
                "IT 모발일" : "컴퓨터/인터넷",
                "대학교재" : "강의지원도서",
                "수험서 자격증" : "강의지원도서",
                "잡지" : "국외 eBook",
                "해외원서": "국외 eBook",
                "오디오북": "국외 eBook",
                "크레마 (전자책 단말기)": "국외 eBook"
                
}

# %%
def create_url(category_number):
    url = "http://www.yes24.com/24/category/bestseller?CategoryNumber={0}&sumgb=07&FetchSize=80".format(category_number)

    return url

# %%
def create_url2(category_number):
    url = "http://www.yes24.com/24/category/bestseller?CategoryNumber={0}&sumgb=07&FetchSize=20&PageNumber=2".format(category_number)

    return url

# %%
bookss = []
for key, value in category_num.items():
    rank = 0
    crolling_url = create_url(value)
    html = requests.get(crolling_url).text
    soup = BeautifulSoup(html, 'html.parser')
    books = soup.select('td.goodsTxtInfo')
    
    
    

    for book in books:
        title = book.select('p:nth-child(1)')[0].text
        price = book.select('p:nth-child(3) > span.priceB')[0].text
        info = book.select('div.aupu')[0].text
        if info.count('|') ==3:
            pass
        else:
            writer = info.split('|')[0]
        
            publisher = info.split('|')[1]

            date = info.split('|')[2]

        stars = book.select('p.review > img')
        
        star_content = 0
        star_edit = 0

        if stars==None:
                    
                star_content = 0
                star_edit = 0
                
        else:

        
            for star in stars[:5]:
                
                if star['src'] == 'http://image.yes24.com/sysimage/interface/StarOn.gif':
                    
                    star_content += 1

            for star in stars[5:]:

                if star['src'] == 'http://image.yes24.com/sysimage/interface/StarOn.gif':
        
                    star_edit += 1
        

        
        rank +=1
        bookss.append([rank,title,writer, publisher, date,price, star_content,star_edit,key]) # 80 add

    crolling_url2 = create_url2(value)
    html2 = requests.get(crolling_url2).text
    soup2 = BeautifulSoup(html2, 'html.parser')
    books2 = soup2.select('td.goodsTxtInfo')

        
    for book in books2:
        title = book.select('p:nth-child(1)')[0].text
        price = book.select('p:nth-child(3) > span.priceB')[0].text
        info = book.select('div.aupu')[0].text
        
        if info.count('|') ==3:
            pass
        else:
            writer = info.split('|')[0]
        
            publisher = info.split('|')[1]

            date = info.split('|')[2]

        publisher = info.split('|')[1]

        date = info.split('|')[2]

        stars = book.select('p.review > img')
        
        star_content = 0
        star_edit = 0

        if stars==None:
                    
                star_content = 0
                star_edit = 0
                
        else:

        
            for star in stars[:5]:
                
                if star['src'] == 'http://image.yes24.com/sysimage/interface/StarOn.gif':
                    
                    star_content += 1

            for star in stars[5:]:

                if star['src'] == 'http://image.yes24.com/sysimage/interface/StarOn.gif':
        
                    star_edit += 1
        

   
        rank +=1
        
        bookss.append([rank,title,writer, publisher, date,price, star_content,star_edit,key]) # 20 add

# %%
df = pd.DataFrame(bookss, columns=['yes24_rank','제목','yes24_writer', 'yes24_company','yes24_date','yes24_price' ,'yes24_star_content','yes24_star_edit','yes24_gener'])

df['yes24_date'] = df['yes24_date'].str.replace(pat=r'[^A-Za-z0-9가-힣]', repl=r' ', regex=True)
df['제목'] = df['제목'].str.replace(pat=r'[^A-Za-z0-9가-힣]', repl=r' ', regex=True)
df['yes24_writer'] = df['yes24_writer'].str.replace(pat=r'[^A-Za-z0-9가-힣]', repl=r' ', regex=True)
df['yes24_company'] = df['yes24_company'].str.replace(pat=r'[^A-Za-z0-9가-힣]', repl=r' ', regex=True)


for i in ['eBook','EPUB','완결','COMIC','PDF']:
    df['제목'] = df['제목'].str.replace(pat=i, repl=r' ', regex=True)


func = lambda x: name_mapping.get(x, x)


df['sm_gener'] = df.yes24_gener.map(func)
df['time_stamp'] = datetime.now()

# %%
df
# Out:
#       yes24_rank                                                 제목  \
# 0              1           난잡하고 불순한
# 1              2        조건  만남  삽화본                             ...
# 2              3                      세트  오빠 손은 약손  외전 포함   총2권
# 3              4           토굴 공주
# 4              5                       세트  오  담에 핀 꽃  개정판   총3권
# ...          ...                                                ...
# 2117          16        How Not to Run for Class President      ...
# 2118          17        The Year of Magical Thinking            ...
# 2119          18             Wonder
# 2120          19        A to Z Mysteries   The Deadly Dungeon   ...
# 2121          20        Princess Ellie s Holiday Adventure      ...
#
#                                            yes24_writer  \
# 0      얀yan 저                                       ...
# 1      문정민 저                                        ...
# 2      금나래 저                                        ...
# 3      함초롱 저                                        ...
# 4      박영 저                                         ...
# ...                                                 ...
# 2117   James Fallon 저                               ...
# 2118   Joan Didion 저                                ...
# 2119   R  J  Palacio 저                              ...
# 2120   Ron Roy 저                                    ...
# 2121   Diana Kimpton 저                              ...
#
#                                           yes24_company  \
# 0        해피북스투유
# 1            로아
# 2            텐북
# 3          제로노블
# 4           플로린
# ...                                                 ...
# 2117   Penguin Publishing Group                     ...
# 2118   Knopf Doubleday Publishing Group             ...
# 2119   Random House Children s Books                ...
# 2120   Random House Children s Books                ...
# 2121   Usborne Publishing Ltd                       ...
#
#                                        yes24_date yes24_price  \
# 0      2023년 02월                                       3,330원
# 1      2021년 05월                                       3,000원
# 2      2021년 05월                                       4,200원
# 3      2022년 12월                                       3,800원
# 4      2023년 02월                                       9,450원
# ...                                           ...         ...
# 2117   2013년 10월                                       6,000원
# 2118   2007년 02월                                      14,500원
# 2119   2012년 02월                                      20,500원
# 2120   2009년 09월                                       7,000원
# 2121   2005년 05월                                       1,000원
#
#       yes24_star_content  yes24_star_edit    yes24_gener  sm_gener  \
# 0                      3                3            로맨스        문학
# 1                      4                4            로맨스        문학
# 2                      4                4            로맨스        문학
# 3                      4                4            로맨스        문학
# 4                      0                0            로맨스        문학
# ...                  ...              ...            ...       ...
# 2117                   0                0  크레마 (전자책 단말기)  국외 eBook
# 2118                   5                5  크레마 (전자책 단말기)  국외 eBook
# 2119                   5                5  크레마 (전자책 단말기)  국외 eBook
# 2120                   0                0  크레마 (전자책 단말기)  국외 eBook
# 2121                   4                4  크레마 (전자책 단말기)  국외 eBook
#
#                      time_stamp
# 0    2023-02-21 23:09:57.534862
# 1    2023-02-21 23:09:57.534862
# 2    2023-02-21 23:09:57.534862
# 3    2023-02-21 23:09:57.534862
# 4    2023-02-21 23:09:57.534862
# ...                         ...
# 2117 2023-02-21 23:09:57.534862
# 2118 2023-02-21 23:09:57.534862
# 2119 2023-02-21 23:09:57.534862
# 2120 2023-02-21 23:09:57.534862
# 2121 2023-02-21 23:09:57.534862
#
# [2122 rows x 11 columns]

# %%
df['yes24_date'] = df['yes24_date'].str.strip()

df['yes24_date'] = df['yes24_date'].str.replace(pat='년 ', repl = '-',regex=True)
df['yes24_date'] = df['yes24_date'].str.replace(pat='월', repl = '',regex=True)
df['yes24_date'] = df['yes24_date'].str.strip()
df['yes24_date']=pd.to_datetime(df['yes24_date'], format='%Y-%m')


for j in ['원',',']:
    df['yes24_price'] = df['yes24_price'].str.replace(pat=j, repl = '',regex=True)
    df['yes24_price'] = df['yes24_price'].str.strip()
df['yes24_price'] = pd.to_numeric(df['yes24_price'])

# %%
df = df[['yes24_rank','제목','yes24_writer', 'yes24_company','yes24_date','yes24_price' ,'yes24_star_content','yes24_star_edit','yes24_gener','sm_gener','time_stamp']]

df.to_csv('yes24.csv', index= False, encoding= 'utf-8')

# %%
json = df.to_json(orient = 'records',force_ascii=False)
print(json)
# Out:
# [{"yes24_rank":1,"제목":"      난잡하고 불순한                                ","yes24_writer":" 얀yan 저                                                            ","yes24_company":" 해피북스투유                                        ","yes24_date":1675209600000,"yes24_price":3330,"yes24_star_content":3,"yes24_star_edit":3,"yes24_gener":"로맨스","sm_gener":"문학","time_stamp":1677020997534},{"yes24_rank":2,"제목":"      조건  만남  삽화본                                 ","yes24_writer":" 문정민 저                                                            ","yes24_company":" 로아                                        ","yes24_date":1619827200000,"yes24_price":3000,"yes24_star_content":4,"yes24_star_edit":4,"yes24_gener":"로맨스","sm_gener":"문학","time_stamp":1677020997534},{"yes24_rank":3,"제목":"       세트  오빠 손은 약손  외전 포함   총2권    ","yes24_writer":" 금나래 저                                                            ","yes24_company":" 텐북                                        ","yes24_date":1619827200000,"yes24_price":4200,"yes24_star_content":4,"yes24_star_edit":4,"yes24_gener":"로맨스","sm_gener":"문학","time_stamp":1677020997534},{"yes24_rank":4,"제목":"      토굴 공주                                   ","yes24_writer":" 함초롱 저                                                            ","yes24_company":" 제로노블                                        ","yes24_date":1669852800000,"yes24_price":3800,"yes24_star_content":4,"yes24_star_edit":4,"yes24_gener":"로맨스","sm_gener":"문학","time_stamp":1677020997534},{"yes24_rank":5,"제목":"       세트  오  담에 핀 꽃  개정판   총3권    ","yes24_writer":" 박영 저                                                            ","yes24_company":" 플로린                                        ","yes24_date":1675209600000,"yes24_price":9450,"yes24_star_content":0,"yes24_star_edit":0,"yes24_gener":"로맨스","sm_gener":"문학","time_stamp":1677020997534},{"yes24_rank":6,"제목":"      별채에는 불이 꺼지지 않는다                                   ","yes24_writer":" 정은동 저                                                            ","yes24_company":" 텐북                                        ","yes24_date":1659312000000,"yes24_price":2970,"yes24_star_content":4,"yes24_star_edit":4,"yes24_gener":"로맨스","sm_gener":"문학","time_stamp":1677020997534},{"yes24_rank":7,"제목":"      몸태질                                ","yes24_writer":" 금단 저                                                            ","yes24_company":" 라떼북                                        ","yes24_date":1675209600000,"yes24_price":3240,"yes24_star_content":3,"yes24_star_edit":3,"yes24_gener":"로맨스","sm_gener":"문학","time_stamp":1677020997534},{"yes24_rank":8,"제목":"      오  담에 핀 꽃  개정판                                    ","yes24_writer":" 박영 저                                                            ","yes24_company":" 플로린                                        ","yes24_date":1675209600000,"yes24_price":3150,"yes24_star_content":0,"yes24_star_edit":0,"yes24_gener":"로맨스","sm_gener":"문학","time_stamp":1677020997534},{"yes24_rank":9,"제목":"      마네킹 365                                ","yes24_writer":" 황금뽀찌 저                                                            ","yes24_company":" 누아르                                        ","yes24_date":1675209600000,"yes24_price":990,"yes24_star_content":0,"yes24_star_edit":0,"yes24_gener":"로맨스","sm_gener":"문학","time_stamp":1677020997534},{"yes24_rank":10,"제목":"      불순종 Impure species                                    ","yes24_writer":" 피오렌티 저                                                            ","yes24_company":" 텐북                                        ","yes24_date":1661990400000,"yes24_price":3600,"yes24_star_content":4,"yes24_star_edit":4,"yes24_gener":"로맨스","sm_gener":"문학","time_stamp":1677020997534},{"yes24_rank":11,"제목":"      느와르 급발진주의                                ","yes24_writer":" 초록개 저                                                            ","yes24_company":" 스칼렛                                        ","yes24_date":1675209600000,"yes24_price":3420,"yes24_star_content":4, ...

# %%
for j in json:

    es.index(

        index = 'yes24_best',
        
        document = j
            )
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# c:\AWS_ElasticCloud\yes24_Category.ipynb 셀 15 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/AWS_ElasticCloud/yes24_Category.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> for j in json:
# ----> <a href='vscode-notebook-cell:/c%3A/AWS_ElasticCloud/yes24_Category.ipynb#X42sZmlsZQ%3D%3D?line=2'>3</a>     es.index(
#       <a href='vscode-notebook-cell:/c%3A/AWS_ElasticCloud/yes24_Category.ipynb#X42sZmlsZQ%3D%3D?line=3'>4</a>
#       <a href='vscode-notebook-cell:/c%3A/AWS_ElasticCloud/yes24_Category.ipynb#X42sZmlsZQ%3D%3D?line=4'>5</a>         index = 'yes24_best',
#       <a href='vscode-notebook-cell:/c%3A/AWS_ElasticCloud/yes24_Category.ipynb#X42sZmlsZQ%3D%3D?line=5'>6</a>
#       <a href='vscode-notebook-cell:/c%3A/AWS_ElasticCloud/yes24_Category.ipynb#X42sZmlsZQ%3D%3D?line=6'>7</a>         document = j
#       <a href='vscode-notebook-cell:/c%3A/AWS_ElasticCloud/yes24_Category.ipynb#X42sZmlsZQ%3D%3D?line=7'>8</a>             )
#
# File c:\Users\rlawl\AppData\Local\Programs\Python\Python310\lib\site-packages\elasticsearch\_sync\client\utils.py:414, in _rewrite_parameters.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     411         except KeyError:
#     412             pass
# --> 414 return api(*args, **kwargs)
#
# File c:\Users\rlawl\AppData\Local\Programs\Python\Python310\lib\site-packages\elasticsearch\_sync\client\__init__.py:2264, in Elasticsearch.index(self, index, document, id, error_trace, filter_path, human, if_primary_term, if_seq_no, op_type, pipeline, pretty, refresh, require_alias, routing, timeout, version, version_type, wait_for_active_shards)
#    2262 __body = document
#    2263 __headers = {"accept": "application/json", "content-type": "application/json"}
# -> 2264 return self.perform_request(  # type: ignore[return-value]
#    2265     __method, __path, params=__query, headers=__headers, body=__body
#    2266 )
#
# File c:\Users\rlawl\AppData\Local\Programs\Python\Python310\lib\site-packages\elasticsearch\_sync\client\_base.py:320, in BaseClient.perform_request(self, method, path, params, headers, body)
#     317         except (ValueError, KeyError, TypeError):
#     318             pass
# --> 320     raise HTTP_EXCEPTIONS.get(meta.status, ApiError)(
#     321         message=message, meta=meta, body=resp_body
#     322     )
#     324 # 'X-Elastic-Product: Elasticsearch' should be on every 2XX response.
#     325 if not self._verified_elasticsearch:
#     326     # If the header is set we mark the server as verified.
#
# BadRequestError: BadRequestError(400, 'mapper_parsing_exception', 'failed to parse')
