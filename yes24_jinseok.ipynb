# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
category_num = {
                "로맨스":"017001046",
                "BL": "017001064",
                "만화":"017001038",
                "판타지 무협": "017001049",
                "소설": "017001045",
                "경제 경영" : "017001047",
                "라이트노벨" : "017001063",
                "에세이 시" : "017001050",
                "인문" : "017001048",
                "사회 정치" : "017001051",
                "자기계발" : "017001054",
                "역사" : "017001052",
                "종교" : "017001053",
                "예술 대중문화" : "017001056",
                "자연과학" : "017001055",
                "가정 살림" : "017001042",
                "건강 취미 여행" : "017001043",
                "어린이 유아" : "017001058",
                "청소년" : "017001059",
                "국어 외국어" : "017001060",
                "IT 모발일" : "017001040",
                "대학교재" : "017001041",
                "수험서 자격증" : "017001061",
                "잡지" : "017001036",
                "해외원서": "017001032",
                "오디오북": "017001032",
                "크레마 (전자책 단말기)": "017001032"
                
}

# %%
name_mapping = {
                "로맨스":"문학",
                "BL": "문학",
                "만화":"문학",
                "판타지 무협": "문학",
                "소설": "문학",
                "경제 경영" : "경제/비즈니스",
                "라이트노벨" : "문학",
                "에세이 시" : "에세이/산문",
                "인문" : "인문",
                "사회 정치" : "인문",
                "자기계발" : "인문",
                "역사" : "인문",
                "종교" : "인문",
                "예술 대중문화" : "가정/생활",
                "자연과학" : "자연/과학",
                "가정 살림" : "가정/생활",
                "건강 취미 여행" : "가정/생활",
                "어린이 유아" : "가정/생활",
                "청소년" : "가정/생활",
                "국어 외국어" : "외국어",
                "IT 모발일" : "컴퓨터/인터넷",
                "대학교재" : "강의지원도서",
                "수험서 자격증" : "강의지원도서",
                "잡지" : "국외 eBook",
                "해외원서": "국외 eBook",
                "오디오북": "국외 eBook",
                "크레마 (전자책 단말기)": "국외 eBook"
                
}

# %%
def create_url(category_number):
    url = "http://www.yes24.com/24/category/bestseller?CategoryNumber={0}&sumgb=07&FetchSize=80".format(category_number)

    return url

# %%
def create_url2(category_number):
    url = "http://www.yes24.com/24/category/bestseller?CategoryNumber={0}&sumgb=07&FetchSize=20&PageNumber=2".format(category_number)

    return url

# %%
bookss = []
for key, value in category_num.items():
    rank = 0
    crolling_url = create_url(value)
    html = requests.get(crolling_url).text
    soup = BeautifulSoup(html, 'html.parser')#dd
    books = soup.select('td.goodsTxtInfo')
    
    
    

    for book in books:
        title = book.select('p:nth-child(1)')[0].text
        price = book.select('p:nth-child(3) > span.priceB')[0].text
        info = book.select('div.aupu')[0].text
        if info.count('|') ==3:
            pass
        else:
            writer = info.split('|')[0]
        
            publisher = info.split('|')[1]

            date = info.split('|')[2]

        stars = book.select('p.review > img')
        
        star_content = 0
        star_edit = 0

        if stars==None:
                    
                star_content = 0
                star_edit = 0
                
        else:

        
            for star in stars[:5]:
                
                if star['src'] == 'http://image.yes24.com/sysimage/interface/StarOn.gif':
                    
                    star_content += 1

            for star in stars[5:]:

                if star['src'] == 'http://image.yes24.com/sysimage/interface/StarOn.gif':
        
                    star_edit += 1
        

        #print(key,title, writer, publisher, date, star_content,star_edit)
        rank +=1
        bookss.append([rank,title,writer, publisher, date,price, star_content,star_edit,key]) # 80 add

    crolling_url2 = create_url2(value)
    html2 = requests.get(crolling_url2).text
    soup2 = BeautifulSoup(html2, 'html.parser')
    books2 = soup2.select('td.goodsTxtInfo')

        
    for book in books2:
        title = book.select('p:nth-child(1)')[0].text
        price = book.select('p:nth-child(3) > span.priceB')[0].text
        info = book.select('div.aupu')[0].text
        
        if info.count('|') ==3:
            pass
        else:
            writer = info.split('|')[0]
        
            publisher = info.split('|')[1]

            date = info.split('|')[2]

        publisher = info.split('|')[1]

        date = info.split('|')[2]

        stars = book.select('p.review > img')
        
        star_content = 0
        star_edit = 0

        if stars==None:
                    
                star_content = 0
                star_edit = 0
                
        else:

        
            for star in stars[:5]:
                
                if star['src'] == 'http://image.yes24.com/sysimage/interface/StarOn.gif':
                    
                    star_content += 1

            for star in stars[5:]:

                if star['src'] == 'http://image.yes24.com/sysimage/interface/StarOn.gif':
        
                    star_edit += 1
        

        #print(key,title, writer, publisher, date, star_content,star_edit)
        rank +=1
        
        bookss.append([rank,title,writer, publisher, date,price, star_content,star_edit,key]) # 20 add

# %%
bookss
# Out:
# [[1,
#   '[eBook]   난잡하고 불순한(EPUB) \r\n            \r\n            ',
#   '\n얀yan 저  \r\n                \r\n                \r\n                    ',
#   ' 해피북스투유\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,330원',
#   3,
#   3,
#   '로맨스'],
#  [2,
#   '[eBook]   조건, 만남 (삽화본)(EPUB) \r\n            \r\n            ',
#   '\n문정민 저  \r\n                \r\n                \r\n                    ',
#   ' 로아\r\n                \r\n                    ',
#   ' 2021년 05월\r\n                 \r\n            ',
#   '3,000원',
#   4,
#   4,
#   '로맨스'],
#  [3,
#   '[eBook]   [세트] 오빠 손은 약손 (외전 포함) (총2권/완결)\n',
#   '\n금나래 저  \r\n                \r\n                \r\n                    ',
#   ' 텐북\r\n                \r\n                    ',
#   ' 2021년 05월\r\n                 \r\n            ',
#   '4,200원',
#   4,
#   4,
#   '로맨스'],
#  [4,
#   '[eBook]   토굴 공주(EPUB, 완결) \r\n            \r\n            ',
#   '\n함초롱 저  \r\n                \r\n                \r\n                    ',
#   ' 제로노블\r\n                \r\n                    ',
#   ' 2022년 12월\r\n                 \r\n            ',
#   '3,800원',
#   4,
#   4,
#   '로맨스'],
#  [5,
#   '[eBook]   [세트] 오, 담에 핀 꽃 (개정판) (총3권/완결)\n',
#   '\n박영 저  \r\n                \r\n                \r\n                    ',
#   ' 플로린\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '9,450원',
#   0,
#   0,
#   '로맨스'],
#  [6,
#   '[eBook]   별채에는 불이 꺼지지 않는다(EPUB, 완결) \r\n            \r\n            ',
#   '\n정은동 저  \r\n                \r\n                \r\n                    ',
#   ' 텐북\r\n                \r\n                    ',
#   ' 2022년 08월\r\n                 \r\n            ',
#   '2,970원',
#   4,
#   4,
#   '로맨스'],
#  [7,
#   '[eBook]   몸태질(EPUB) \r\n            \r\n            ',
#   '\n금단 저  \r\n                \r\n                \r\n                    ',
#   ' 라떼북\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,240원',
#   3,
#   3,
#   '로맨스'],
#  [8,
#   '[eBook]   오, 담에 핀 꽃 (개정판)(EPUB, 완결) \r\n            \r\n            ',
#   '\n박영 저  \r\n                \r\n                \r\n                    ',
#   ' 플로린\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,150원',
#   0,
#   0,
#   '로맨스'],
#  [9,
#   '[eBook]   마네킹 365(EPUB) \r\n            \r\n            ',
#   '\n황금뽀찌 저  \r\n                \r\n                \r\n                    ',
#   ' 누아르\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '990원',
#   0,
#   0,
#   '로맨스'],
#  [10,
#   '[eBook]   불순종(Impure species)(EPUB, 완결) \r\n            \r\n            ',
#   '\n피오렌티 저  \r\n                \r\n                \r\n                    ',
#   ' 텐북\r\n                \r\n                    ',
#   ' 2022년 09월\r\n                 \r\n            ',
#   '3,600원',
#   4,
#   4,
#   '로맨스'],
#  [11,
#   '[eBook]   느와르 급발진주의(EPUB) \r\n            \r\n            ',
#   '\n초록개 저  \r\n                \r\n                \r\n                    ',
#   ' 스칼렛\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,420원',
#   4,
#   4,
#   '로맨스'],
#  [12,
#   '[eBook]   구숙, 만복을 빌어요(EPUB) \r\n            \r\n            ',
#   '\n구월류화 저  \r\n                \r\n                \r\n                    ',
#   ' 태평\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,200원',
#   4,
#   4,
#   '로맨스'],
#  [13,
#   '[eBook]   화제의 여학생(EPUB, 완결) \r\n            \r\n            ',
#   '\n연초 저  \r\n                \r\n                \r\n                    ',
#   ' 라떼북\r\n                \r\n                    ',
#   ' 2019년 02월\r\n                 \r\n            ',
#   '3,420원',
#   4,
#   4,
#   '로맨스'],
#  [14,
#   '[eBook]   새장 속의 딸(EPUB) \r\n            \r\n            ',
#   '\n진수성찬 저  \r\n                \r\n                \r\n                    ',
#   ' 로튼로즈\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '2,700원',
#   3,
#   3,
#   '로맨스'],
#  [15,
#   '[eBook]   스탯 999+ 엄친아의 -1(EPUB) \r\n            \r\n            ',
#   '\n얌쟘 저  \r\n                \r\n                \r\n                    ',
#   ' 텐북\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '3,510원',
#   4,
#   3,
#   '로맨스'],
#  [16,
#   '[eBook]   옷소매 붉은 끝동(EPUB, 완결) \r\n            \r\n            ',
#   '\n강미강 저  \r\n                \r\n                \r\n                    ',
#   ' 도서출판 청어람\r\n                \r\n                    ',
#   ' 2017년 06월\r\n                 \r\n            ',
#   '2,800원',
#   4,
#   4,
#   '로맨스'],
#  [17,
#   '[eBook]   아내 노릇(EPUB, 완결) \r\n            \r\n            ',
#   '\n솔해 저  \r\n                \r\n                \r\n                    ',
#   ' 로망로즈\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '3,000원',
#   4,
#   4,
#   '로맨스'],
#  [18,
#   '[eBook]   남사친의 아이입니다(EPUB, 완결) \r\n            \r\n            ',
#   '\n글이나 저  \r\n                \r\n                \r\n                    ',
#   ' 신영미디어\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,060원',
#   0,
#   0,
#   '로맨스'],
#  [19,
#   '[eBook]   부부 교체(EPUB) \r\n            \r\n            ',
#   '\n은차현 저  \r\n                \r\n                \r\n                    ',
#   ' 에피루스\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,200원',
#   0,
#   0,
#   '로맨스'],
#  [20,
#   '[eBook]   강산미인모(EPUB) \r\n            \r\n            ',
#   '\n수당(袖唐) 저, 연운 역 저  \r\n                \r\n                \r\n                    ',
#   ' 답인(答人)\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,000원',
#   0,
#   0,
#   '로맨스'],
#  [21,
#   '[eBook]   나체 초밥(EPUB) \r\n            \r\n            ',
#   '\n탱글탱글 저  \r\n                \r\n                \r\n                    ',
#   ' 로튼로즈\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '990원',
#   0,
#   0,
#   '로맨스'],
#  [22,
#   '[eBook]   논 트리거(EPUB, 완결) \r\n            \r\n            ',
#   '\n몽슈 저  \r\n                \r\n                \r\n                    ',
#   ' 플로린\r\n                \r\n                    ',
#   ' 2022년 03월\r\n                 \r\n            ',
#   '4,050원',
#   4,
#   4,
#   '로맨스'],
#  [23,
#   '[eBook]   마지막 여행이 끝나면(EPUB, 완결) \r\n            \r\n            ',
#   '\n하늘가리기 저  \r\n                \r\n                \r\n                    ',
#   ' 피오렛\r\n                \r\n                    ',
#   ' 2021년 06월\r\n                 \r\n            ',
#   '3,700원',
#   4,
#   4,
#   '로맨스'],
#  [24,
#   '[eBook]   시칠리아의 남자(EPUB) \r\n            \r\n            ',
#   '\n문희 저  \r\n                \r\n                \r\n                    ',
#   ' 루체\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '4,500원',
#   0,
#   0,
#   '로맨스'],
#  [25,
#   '[eBook]   짝사랑남 최면으로 ××하기(EPUB) \r\n            \r\n            ',
#   '\n구르는머위 저  \r\n                \r\n                \r\n                    ',
#   ' 로튼로즈\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '900원',
#   0,
#   0,
#   '로맨스'],
#  [26,
#   '[eBook]   옥당금규\n',
#   '\n한청낙화 저  \r\n                \r\n                \r\n                    ',
#   ' 답인(答人)\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '4,400원',
#   0,
#   0,
#   '로맨스'],
#  [27,
#   '[eBook]   수면 임신 (삽화본)(EPUB) \r\n            \r\n            ',
#   '\n문정민 저  \r\n                \r\n                \r\n                    ',
#   ' 로아\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '2,000원',
#   3,
#   3,
#   '로맨스'],
#  [28,
#   '[eBook]   임파스토(Impasto)(EPUB, 완결) \r\n            \r\n            ',
#   '\n우지혜 저  \r\n                \r\n                \r\n                    ',
#   ' 폴라리스\r\n                \r\n                    ',
#   ' 2022년 12월\r\n                 \r\n            ',
#   '3,300원',
#   4,
#   4,
#   '로맨스'],
#  [29,
#   '[eBook]   야성의 숲(EPUB, 완결) \r\n            \r\n            ',
#   '\n이내리 저  \r\n                \r\n                \r\n                    ',
#   ' 피플앤스토리\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,500원',
#   0,
#   0,
#   '로맨스'],
#  [30,
#   '[eBook]   다정한 함정(EPUB) \r\n            \r\n            ',
#   '\n허도윤 저  \r\n                \r\n                \r\n                    ',
#   ' 이지콘텐츠\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,600원',
#   3,
#   3,
#   '로맨스'],
#  [31,
#   '[eBook]   우리가 가족이 될 수 있을까요?(EPUB) \r\n            \r\n            ',
#   '\n한이림 저  \r\n                \r\n                \r\n                    ',
#   ' 연담\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '4,000원',
#   4,
#   5,
#   '로맨스'],
#  [32,
#   '[eBook]   여름의 밀도(EPUB) \r\n            \r\n            ',
#   '\n채랑비 저  \r\n                \r\n                \r\n                    ',
#   ' SOME\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,690원',
#   3,
#   4,
#   '로맨스'],
#  [33,
#   '[eBook]   형부에게 박히는 밤(EPUB) \r\n            \r\n            ',
#   '\n경조사매니아 저  \r\n                \r\n                \r\n                    ',
#   ' 로튼로즈\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '900원',
#   0,
#   0,
#   '로맨스'],
#  [34,
#   '[eBook]   오빠 친구인 거 몰랐어?(EPUB) \r\n            \r\n            ',
#   '\n요안나 저  \r\n                \r\n                \r\n                    ',
#   '  Renee\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,500원',
#   4,
#   4,
#   '로맨스'],
#  [35,
#   '[eBook]   괴물 아가씨와 성기사(EPUB, 완결) \r\n            \r\n            ',
#   '\n손금 저  \r\n                \r\n                \r\n                    ',
#   ' 로즈엔\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,060원',
#   4,
#   4,
#   '로맨스'],
#  [36,
#   '[eBook]   조폭 아빠의 XX 가르침(EPUB) \r\n            \r\n            ',
#   '\n심솜 저  \r\n                \r\n                \r\n                    ',
#   ' 로튼로즈\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '900원',
#   0,
#   0,
#   '로맨스'],
#  [37,
#   '[eBook]   소꿉친구 공략기(EPUB) \r\n            \r\n            ',
#   '\n곽두팔 저  \r\n                \r\n                \r\n                    ',
#   ' 미스틱레드\r\n                \r\n                    ',
#   ' 2022년 09월\r\n                 \r\n            ',
#   '3,200원',
#   4,
#   4,
#   '로맨스'],
#  [38,
#   '[eBook]   자극질(EPUB, 완결) \r\n            \r\n            ',
#   '\n블랙라엘 저  \r\n                \r\n                \r\n                    ',
#   ' 리얼라엘\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '2,600원',
#   4,
#   4,
#   '로맨스'],
#  [39,
#   '[eBook]   애착 유모(EPUB) \r\n            \r\n            ',
#   '\n이사과 저  \r\n                \r\n                \r\n                    ',
#   ' 에이블\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '2,700원',
#   3,
#   3,
#   '로맨스'],
#  [40,
#   '[eBook]   너를 속이는 밤(EPUB, 완결) \r\n            \r\n            ',
#   '\n정은동 저  \r\n                \r\n                \r\n                    ',
#   ' 폴라리스\r\n                \r\n                    ',
#   ' 2022년 06월\r\n                 \r\n            ',
#   '4,200원',
#   4,
#   4,
#   '로맨스'],
#  [41,
#   '[eBook]   악역 소녀는 사랑받기가 부끄러워요(EPUB, 완결) \r\n            \r\n            ',
#   '\n류희온 저  \r\n                \r\n                \r\n                    ',
#   ' 크레센도\r\n                \r\n                    ',
#   ' 2022년 07월\r\n                 \r\n            ',
#   '4,000원',
#   4,
#   4,
#   '로맨스'],
#  [42,
#   '[eBook]   위태로운(EPUB) \r\n            \r\n            ',
#   '\n고성후 저  \r\n                \r\n                \r\n                    ',
#   ' 텐북\r\n                \r\n                    ',
#   ' 2021년 03월\r\n                 \r\n            ',
#   '3,300원',
#   4,
#   4,
#   '로맨스'],
#  [43,
#   '[eBook]   [세트] 남사친의 아이입니다 (총2권/완결)\n',
#   '\n글이나 저  \r\n                \r\n                \r\n                    ',
#   ' 신영미디어\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '6,120원',
#   0,
#   0,
#   '로맨스'],
#  [44,
#   '[eBook]   지금은 XX물 소리 녹음중입니다(EPUB) \r\n            \r\n            ',
#   '\n벌리바바 저  \r\n                \r\n                \r\n                    ',
#   ' 로튼로즈\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '900원',
#   0,
#   0,
#   '로맨스'],
#  [45,
#   '[eBook]   미아(EPUB) \r\n            \r\n            ',
#   '\n도개비 저  \r\n                \r\n                \r\n                    ',
#   ' 봄미디어\r\n                \r\n                    ',
#   ' 2020년 01월\r\n                 \r\n            ',
#   '3,800원',
#   4,
#   4,
#   '로맨스'],
#  [46,
#   '[eBook]   비싼 놈(EPUB, 완결) \r\n            \r\n            ',
#   '\n얀소흔 저  \r\n                \r\n                \r\n                    ',
#   ' 이브\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,500원',
#   4,
#   4,
#   '로맨스'],
#  [47,
#   '[eBook]   악녀의 문구점에 오지 마세요!(EPUB) \r\n            \r\n            ',
#   '\n여로은 저  \r\n                \r\n                \r\n                    ',
#   ' 연담\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,600원',
#   4,
#   4,
#   '로맨스'],
#  [48,
#   '[eBook]   반역자는 황후를 취한다(EPUB) \r\n            \r\n            ',
#   '\n구르는머위 저  \r\n                \r\n                \r\n                    ',
#   ' 로튼로즈\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '900원',
#   0,
#   0,
#   '로맨스'],
#  [49,
#   '[eBook]   그날 밤, 조폭과 함께였던 것에 대한 변론(EPUB) \r\n            \r\n            ',
#   '\n난설 저  \r\n                \r\n                \r\n                    ',
#   ' 늘솔 북스\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '1,170원',
#   4,
#   4,
#   '로맨스'],
#  [50,
#   '[eBook]   연옥의 성녀(EPUB, 완결) \r\n            \r\n            ',
#   '\n단개비 저  \r\n                \r\n                \r\n                    ',
#   ' 디앤씨북스\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,330원',
#   5,
#   5,
#   '로맨스'],
#  [51,
#   '[eBook]   난기류(EPUB) \r\n            \r\n            ',
#   '\n마뇽 저  \r\n                \r\n                \r\n                    ',
#   ' 블레슈(Blesshuu)\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '2,250원',
#   3,
#   3,
#   '로맨스'],
#  [52,
#   '[eBook]   적녀의비(EPUB, 완결) \r\n            \r\n            ',
#   '\n천령 저  \r\n                \r\n                \r\n                    ',
#   ' 케이오씨엠\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,000원',
#   0,
#   0,
#   '로맨스'],
#  [53,
#   '[eBook]   남자는 지치지도 않았다(EPUB) \r\n            \r\n            ',
#   '\n시크 저  \r\n                \r\n                \r\n                    ',
#   ' 피플앤스토리\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,500원',
#   4,
#   4,
#   '로맨스'],
#  [54,
#   '[eBook]   습첩(EPUB, 완결) \r\n            \r\n            ',
#   '\n반민초 저  \r\n                \r\n                \r\n                    ',
#   ' Renee\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,000원',
#   4,
#   4,
#   '로맨스'],
#  [55,
#   '[eBook]   회사를 다닙시다(EPUB) \r\n            \r\n            ',
#   '\n우지혜 저  \r\n                \r\n                \r\n                    ',
#   ' 플로레뜨\r\n                \r\n                    ',
#   ' 2022년 10월\r\n                 \r\n            ',
#   '3,500원',
#   4,
#   4,
#   '로맨스'],
#  [56,
#   '[eBook]   결혼 풍습(EPUB) \r\n            \r\n            ',
#   '\n키달 저  \r\n                \r\n                \r\n                    ',
#   ' 오페르툼\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '900원',
#   0,
#   0,
#   '로맨스'],
#  [57,
#   '[eBook]   매일밤 오라버니와 사냥을(EPUB) \r\n            \r\n            ',
#   '\n주화입마 저  \r\n                \r\n                \r\n                    ',
#   ' 늘솔 북스\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '3,000원',
#   4,
#   4,
#   '로맨스'],
#  [58,
#   '[eBook]   세가(EPUB, 완결) \r\n            \r\n            ',
#   '\n목영 저  \r\n                \r\n                \r\n                    ',
#   ' 케이오씨엠\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '3,000원',
#   5,
#   5,
#   '로맨스'],
#  [59,
#   '[eBook]   여동생의 구멍 막아주기(EPUB) \r\n            \r\n            ',
#   '\n마라맛슈가 저  \r\n                \r\n                \r\n                    ',
#   ' 로튼로즈\r\n                \r\n                    ',
#   ' 2022년 12월\r\n                 \r\n            ',
#   '1,000원',
#   4,
#   4,
#   '로맨스'],
#  [60,
#   '[eBook]   신입생 율무의 동아리생활\n',
#   '\n지초가 지천 저  \r\n                \r\n                \r\n                    ',
#   ' 로튼로즈\r\n                \r\n                    ',
#   ' 2022년 11월\r\n                 \r\n            ',
#   '1,000원',
#   4,
#   4,
#   '로맨스'],
#  [61,
#   '[eBook]   야누스의 밤(EPUB, 완결) \r\n            \r\n            ',
#   '\n베리바 저  \r\n                \r\n                \r\n                    ',
#   ' 도서출판 쉼표\r\n                \r\n                    ',
#   ' 2022년 10월\r\n                 \r\n            ',
#   '3,400원',
#   4,
#   4,
#   '로맨스'],
#  [62,
#   '[eBook]   내게 빌어봐(EPUB, 완결) \r\n            \r\n            ',
#   '\n리베냐 저  \r\n                \r\n                \r\n                    ',
#   ' 마담드디키\r\n                \r\n                    ',
#   ' 2022년 07월\r\n                 \r\n            ',
#   '5,200원',
#   4,
#   4,
#   '로맨스'],
#  [63,
#   '[eBook]   그 겨울의 순정(EPUB, 완결) \r\n            \r\n            ',
#   '\n채은 저  \r\n                \r\n                \r\n                    ',
#   ' 텐북\r\n                \r\n                    ',
#   ' 2022년 05월\r\n                 \r\n            ',
#   '4,500원',
#   4,
#   4,
#   '로맨스'],
#  [64,
#   '[eBook]   사냥꾼에게서 도망쳤다(EPUB) \r\n            \r\n            ',
#   '\n죄송한취향 저  \r\n                \r\n                \r\n                    ',
#   ' 시계토끼\r\n                \r\n                    ',
#   ' 2022년 05월\r\n                 \r\n            ',
#   '3,400원',
#   4,
#   4,
#   '로맨스'],
#  [65,
#   '[eBook]   스토커, 스토커(EPUB, 완결) \r\n            \r\n            ',
#   '\n권겨을 저  \r\n                \r\n                \r\n                    ',
#   ' 솔리테어\r\n                \r\n                    ',
#   ' 2020년 12월\r\n                 \r\n            ',
#   '3,500원',
#   4,
#   4,
#   '로맨스'],
#  [66,
#   '[eBook]   인소의 법칙\n',
#   '\n유한려 저  \r\n                \r\n                \r\n                    ',
#   ' 잇북(It Book)\r\n                \r\n                    ',
#   ' 2020년 09월\r\n                 \r\n            ',
#   '4,000원',
#   4,
#   4,
#   '로맨스'],
#  [67,
#   '[eBook]   [세트] 야성의 숲 (총2권/완결)\n',
#   '\n이내리 저  \r\n                \r\n                \r\n                    ',
#   ' 피플앤스토리\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '7,000원',
#   0,
#   0,
#   '로맨스'],
#  [68,
#   '[eBook]   간헐적 파트너(EPUB) \r\n            \r\n            ',
#   '\n늴리리야 저  \r\n                \r\n                \r\n                    ',
#   ' 하트퀸\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,240원',
#   0,
#   0,
#   '로맨스'],
#  [69,
#   '[eBook]   그대에게 하고 싶은 말(EPUB) \r\n            \r\n            ',
#   '\n임수연 저  \r\n                \r\n                \r\n                    ',
#   ' ㈜조은세상\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '2,500원',
#   0,
#   0,
#   '로맨스'],
#  [70,
#   '[eBook]   계략 후배(EPUB) \r\n            \r\n            ',
#   '\n이리안 저  \r\n                \r\n                \r\n                    ',
#   ' 레드립\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '1,530원',
#   0,
#   0,
#   '로맨스'],
#  [71,
#   '[eBook]   사방신께서 내려오셨다-현무편(EPUB) \r\n            \r\n            ',
#   '\n천서래 저  \r\n                \r\n                \r\n                    ',
#   ' 로튼로즈\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '900원',
#   0,
#   0,
#   '로맨스'],
#  [72,
#   '[eBook]   미친 맞선, 미친 놈(EPUB) \r\n            \r\n            ',
#   '\n제타 저  \r\n                \r\n                \r\n                    ',
#   ' ㈜조은세상\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,200원',
#   0,
#   0,
#   '로맨스'],
#  [73,
#   '[eBook]   [세트] 황녀의 유축도우미 (총2권/완결)\n',
#   '\n금죵 저  \r\n                \r\n                \r\n                    ',
#   ' 텐북\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '1,980원',
#   0,
#   0,
#   '로맨스'],
#  [74,
#   '[eBook]   사소한 저주(EPUB) \r\n            \r\n            ',
#   '\n청경 저  \r\n                \r\n                \r\n                    ',
#   ' 인피니티\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '2,400원',
#   0,
#   0,
#   '로맨스'],
#  [75,
#   '[eBook]   나쁜 말이 취향이라(EPUB) \r\n            \r\n            ',
#   '\n크림치즈 저  \r\n                \r\n                \r\n                    ',
#   ' 와이엠북스\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '2,880원',
#   4,
#   4,
#   '로맨스'],
#  [76,
#   '[eBook]   붉은 달의 꽃(EPUB) \r\n            \r\n            ',
#   '\n공호 저  \r\n                \r\n                \r\n                    ',
#   ' 밀리오리지널\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,500원',
#   0,
#   0,
#   '로맨스'],
#  [77,
#   '[eBook]   광한궁의 남자들(EPUB) \r\n            \r\n            ',
#   '\n박윤후 저  \r\n                \r\n                \r\n                    ',
#   ' 릴리스\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '2,610원',
#   0,
#   0,
#   '로맨스'],
#  [78,
#   '[eBook]   젖몸살(EPUB3.0, 완결) \r\n            \r\n            ',
#   '\n요망한 저  \r\n                \r\n                \r\n                    ',
#   ' 캐롯앤스틱\r\n                \r\n                    ',
#   ' 2021년 02월\r\n                 \r\n            ',
#   '1,900원',
#   0,
#   0,
#   '로맨스'],
#  [79,
#   '[eBook]   파파(EPUB) \r\n            \r\n            ',
#   '\n마뇽 저  \r\n                \r\n                \r\n                    ',
#   ' 텐북\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '1,800원',
#   4,
#   4,
#   '로맨스'],
#  [80,
#   '[eBook]   이웃사촌의 xx구멍(EPUB) \r\n            \r\n            ',
#   '\n비아란 저  \r\n                \r\n                \r\n                    ',
#   ' 로튼로즈\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '900원',
#   0,
#   0,
#   '로맨스'],
#  [81,
#   '[eBook]   나체 초밥(EPUB) \r\n            \r\n            ',
#   '\n탱글탱글 저  \r\n                \r\n                \r\n                    ',
#   ' 로튼로즈\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '990원',
#   0,
#   0,
#   '로맨스'],
#  [82,
#   '[eBook]   논 트리거(EPUB, 완결) \r\n            \r\n            ',
#   '\n몽슈 저  \r\n                \r\n                \r\n                    ',
#   ' 플로린\r\n                \r\n                    ',
#   ' 2022년 03월\r\n                 \r\n            ',
#   '4,050원',
#   4,
#   4,
#   '로맨스'],
#  [83,
#   '[eBook]   마지막 여행이 끝나면(EPUB, 완결) \r\n            \r\n            ',
#   '\n하늘가리기 저  \r\n                \r\n                \r\n                    ',
#   ' 피오렛\r\n                \r\n                    ',
#   ' 2021년 06월\r\n                 \r\n            ',
#   '3,700원',
#   4,
#   4,
#   '로맨스'],
#  [84,
#   '[eBook]   시칠리아의 남자(EPUB) \r\n            \r\n            ',
#   '\n문희 저  \r\n                \r\n                \r\n                    ',
#   ' 루체\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '4,500원',
#   0,
#   0,
#   '로맨스'],
#  [85,
#   '[eBook]   짝사랑남 최면으로 ××하기(EPUB) \r\n            \r\n            ',
#   '\n구르는머위 저  \r\n                \r\n                \r\n                    ',
#   ' 로튼로즈\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '900원',
#   0,
#   0,
#   '로맨스'],
#  [86,
#   '[eBook]   옥당금규\n',
#   '\n한청낙화 저  \r\n                \r\n                \r\n                    ',
#   ' 답인(答人)\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '4,400원',
#   0,
#   0,
#   '로맨스'],
#  [87,
#   '[eBook]   수면 임신 (삽화본)(EPUB) \r\n            \r\n            ',
#   '\n문정민 저  \r\n                \r\n                \r\n                    ',
#   ' 로아\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '2,000원',
#   3,
#   3,
#   '로맨스'],
#  [88,
#   '[eBook]   임파스토(Impasto)(EPUB, 완결) \r\n            \r\n            ',
#   '\n우지혜 저  \r\n                \r\n                \r\n                    ',
#   ' 폴라리스\r\n                \r\n                    ',
#   ' 2022년 12월\r\n                 \r\n            ',
#   '3,300원',
#   4,
#   4,
#   '로맨스'],
#  [89,
#   '[eBook]   야성의 숲(EPUB, 완결) \r\n            \r\n            ',
#   '\n이내리 저  \r\n                \r\n                \r\n                    ',
#   ' 피플앤스토리\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,500원',
#   0,
#   0,
#   '로맨스'],
#  [90,
#   '[eBook]   다정한 함정(EPUB) \r\n            \r\n            ',
#   '\n허도윤 저  \r\n                \r\n                \r\n                    ',
#   ' 이지콘텐츠\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,600원',
#   3,
#   3,
#   '로맨스'],
#  [91,
#   '[eBook]   우리가 가족이 될 수 있을까요?(EPUB) \r\n            \r\n            ',
#   '\n한이림 저  \r\n                \r\n                \r\n                    ',
#   ' 연담\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '4,000원',
#   4,
#   5,
#   '로맨스'],
#  [92,
#   '[eBook]   여름의 밀도(EPUB) \r\n            \r\n            ',
#   '\n채랑비 저  \r\n                \r\n                \r\n                    ',
#   ' SOME\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,690원',
#   3,
#   4,
#   '로맨스'],
#  [93,
#   '[eBook]   형부에게 박히는 밤(EPUB) \r\n            \r\n            ',
#   '\n경조사매니아 저  \r\n                \r\n                \r\n                    ',
#   ' 로튼로즈\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '900원',
#   0,
#   0,
#   '로맨스'],
#  [94,
#   '[eBook]   오빠 친구인 거 몰랐어?(EPUB) \r\n            \r\n            ',
#   '\n요안나 저  \r\n                \r\n                \r\n                    ',
#   '  Renee\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,500원',
#   4,
#   4,
#   '로맨스'],
#  [95,
#   '[eBook]   괴물 아가씨와 성기사(EPUB, 완결) \r\n            \r\n            ',
#   '\n손금 저  \r\n                \r\n                \r\n                    ',
#   ' 로즈엔\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,060원',
#   4,
#   4,
#   '로맨스'],
#  [96,
#   '[eBook]   조폭 아빠의 XX 가르침(EPUB) \r\n            \r\n            ',
#   '\n심솜 저  \r\n                \r\n                \r\n                    ',
#   ' 로튼로즈\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '900원',
#   0,
#   0,
#   '로맨스'],
#  [97,
#   '[eBook]   소꿉친구 공략기(EPUB) \r\n            \r\n            ',
#   '\n곽두팔 저  \r\n                \r\n                \r\n                    ',
#   ' 미스틱레드\r\n                \r\n                    ',
#   ' 2022년 09월\r\n                 \r\n            ',
#   '3,200원',
#   4,
#   4,
#   '로맨스'],
#  [98,
#   '[eBook]   자극질(EPUB, 완결) \r\n            \r\n            ',
#   '\n블랙라엘 저  \r\n                \r\n                \r\n                    ',
#   ' 리얼라엘\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '2,600원',
#   4,
#   4,
#   '로맨스'],
#  [99,
#   '[eBook]   애착 유모(EPUB) \r\n            \r\n            ',
#   '\n이사과 저  \r\n                \r\n                \r\n                    ',
#   ' 에이블\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '2,700원',
#   3,
#   3,
#   '로맨스'],
#  [100,
#   '[eBook]   너를 속이는 밤(EPUB, 완결) \r\n            \r\n            ',
#   '\n정은동 저  \r\n                \r\n                \r\n                    ',
#   ' 폴라리스\r\n                \r\n                    ',
#   ' 2022년 06월\r\n                 \r\n            ',
#   '4,200원',
#   4,
#   4,
#   '로맨스'],
#  [1,
#   '[eBook]   [BL] 데이 브레이커(EPUB) \r\n            \r\n            ',
#   '\n체레네 저  \r\n                \r\n                \r\n                    ',
#   ' 문라이트북스\r\n                \r\n                    ',
#   ' 2018년 01월\r\n                 \r\n            ',
#   '3,000원',
#   4,
#   4,
#   'BL'],
#  [2,
#   '[eBook]   [BL] 주먹 구십구(EPUB) \r\n            \r\n            ',
#   '\n마연 저  \r\n                \r\n                \r\n                    ',
#   ' 블러쉬\r\n                \r\n                    ',
#   ' 2022년 01월\r\n                 \r\n            ',
#   '3,200원',
#   4,
#   4,
#   'BL'],
#  [3,
#   '[eBook]   [세트] [BL] 어떤 겨울 이야기 (총2권/완결)\n',
#   '\n클나무 저  \r\n                \r\n                \r\n                    ',
#   ' 라피스\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '5,940원',
#   0,
#   0,
#   'BL'],
#  [4,
#   '[eBook]   [BL] 시나몬 캔디(EPUB, 완결) \r\n            \r\n            ',
#   '\nWhale 저  \r\n                \r\n                \r\n                    ',
#   ' 모드\r\n                \r\n                    ',
#   ' 2022년 11월\r\n                 \r\n            ',
#   '3,600원',
#   4,
#   4,
#   'BL'],
#  [5,
#   '[eBook]   첫사랑이 하고 싶어\n',
#   '\n찬덕 글/KAN 그림  \r\n                \r\n                \r\n                    ',
#   ' 비숲\r\n                \r\n                    ',
#   ' 2021년 09월\r\n                 \r\n            ',
#   '500원',
#   0,
#   0,
#   'BL'],
#  [6,
#   '[eBook]   [루비] 피지 않는 꽃에 물 주기(COMIC, 완결) \r\n            \r\n            ',
#   '\n아가 나오미 저/yoshi 글그림  \r\n                \r\n                \r\n                    ',
#   ' 현대지능개발사\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '2,520원',
#   4,
#   4,
#   'BL'],
#  [7,
#   '[eBook]   [BL] 파이브 바이 파이브(5x5)(EPUB, 완결) \r\n            \r\n            ',
#   '\n이소한 저  \r\n                \r\n                \r\n                    ',
#   ' 텐북\r\n                \r\n                    ',
#   ' 2022년 08월\r\n                 \r\n            ',
#   '4,800원',
#   4,
#   4,
#   'BL'],
#  [8,
#   '[eBook]   [BL] 센차 레플리카(EPUB, 완결) \r\n            \r\n            ',
#   '\n서니주 저  \r\n                \r\n                \r\n                    ',
#   ' BLYNUE 블리뉴\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,800원',
#   4,
#   4,
#   'BL'],
#  [9,
#   '[eBook]   [연재] 미치기 좋은 날 (완전판)\n',
#   '\n유사 저  \r\n                \r\n                \r\n                    ',
#   ' 대원씨아이\r\n                \r\n                    ',
#   ' 2018년 12월\r\n                 \r\n            ',
#   '500원',
#   5,
#   5,
#   'BL'],
#  [10,
#   '[eBook]   [BL] 루트를 거부하는 방법(EPUB, 완결) \r\n            \r\n            ',
#   '\n허니트랩 저  \r\n                \r\n                \r\n                    ',
#   ' 피아체\r\n                \r\n                    ',
#   ' 2020년 07월\r\n                 \r\n            ',
#   '3,600원',
#   4,
#   4,
#   'BL'],
#  [11,
#   '[eBook]   [대여] [루비] 투명한 사랑의 그릇 (한정판)(COMIC) \r\n            \r\n            ',
#   '\nhitomi 글그림  \r\n                \r\n                \r\n                    ',
#   ' 현대지능개발사\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '1,440원',
#   4,
#   4,
#   'BL'],
#  [12,
#   '[eBook]   [BL] 서퍼 ; 스토커 헌터지만 육아하고 있습니다.(EPUB, 완결) \r\n            \r\n            ',
#   '\n글먹SS 저  \r\n                \r\n                \r\n                    ',
#   ' 더클북컴퍼니\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '4,200원',
#   4,
#   4,
#   'BL'],
#  [13,
#   '[eBook]   [BL] 동티(EPUB) \r\n            \r\n            ',
#   '\n소조금 저  \r\n                \r\n                \r\n                    ',
#   ' 모드\r\n                \r\n                    ',
#   ' 2022년 09월\r\n                 \r\n            ',
#   '3,000원',
#   4,
#   4,
#   'BL'],
#  [14,
#   '[eBook]   [BL] 자비를 베푸소서(Miserere Nobis)(EPUB) \r\n            \r\n            ',
#   '\nSISSI 저  \r\n                \r\n                \r\n                    ',
#   ' 블러쉬\r\n                \r\n                    ',
#   ' 2021년 02월\r\n                 \r\n            ',
#   '2,800원',
#   4,
#   4,
#   'BL'],
#  [15,
#   '[eBook]   [BL] 후회하지 않기 위해서(EPUB) \r\n            \r\n            ',
#   '\n버터앙팡 저  \r\n                \r\n                \r\n                    ',
#   ' 요미북스\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '3,000원',
#   0,
#   0,
#   'BL'],
#  [16,
#   '[eBook]   [BL] 플로리스 플롯 (Flawless Plot)(EPUB) \r\n            \r\n            ',
#   '\n이은성 저  \r\n                \r\n                \r\n                    ',
#   ' 블로우\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '2,700원',
#   5,
#   5,
#   'BL'],
#  [17,
#   '[eBook]   [BL] 미치도록 아름다운(EPUB) \r\n            \r\n            ',
#   '\nleefail 저  \r\n                \r\n                \r\n                    ',
#   ' 블루코드\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '3,600원',
#   4,
#   4,
#   'BL'],
#  [18,
#   '[eBook]   [BL] 스파이게임(EPUB, 완결) \r\n            \r\n            ',
#   '\n바크베 저  \r\n                \r\n                \r\n                    ',
#   ' 피아체\r\n                \r\n                    ',
#   ' 2021년 10월\r\n                 \r\n            ',
#   '3,200원',
#   4,
#   4,
#   'BL'],
#  [19,
#   '[eBook]   [BL] 저온화상(EPUB, 완결) \r\n            \r\n            ',
#   '\n꼿발 저  \r\n                \r\n                \r\n                    ',
#   ' BLYNUE 블리뉴\r\n                \r\n                    ',
#   ' 2021년 11월\r\n                 \r\n            ',
#   '4,300원',
#   4,
#   4,
#   'BL'],
#  [20,
#   '[eBook]   [BL] 미필적 고의에 의한 연애사   확정적 고의에 의한 연애사(EPUB, 완결) \r\n            \r\n            ',
#   '\n우주토깽 저  \r\n                \r\n                \r\n                    ',
#   ' 비욘드\r\n                \r\n                    ',
#   ' 2019년 02월\r\n                 \r\n            ',
#   '4,500원',
#   4,
#   4,
#   'BL'],
#  [21,
#   '[eBook]   [BL] 사랑하는 내 아들(EPUB) \r\n            \r\n            ',
#   '\n철푸덕 저  \r\n                \r\n                \r\n                    ',
#   ' 골드핑거\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '1,000원',
#   0,
#   0,
#   'BL'],
#  [22,
#   '[eBook]   [비애] 은목서의 양재사(COMIC, 완결) \r\n            \r\n            ',
#   '\n마미타 글그림  \r\n                \r\n                \r\n                    ',
#   ' 비애코믹스\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,780원',
#   4,
#   4,
#   'BL'],
#  [23,
#   '[eBook]   [BL] 비생산적 관계에 대한 비이성적 고찰(EPUB, 완결) \r\n            \r\n            ',
#   '\n라휘 저  \r\n                \r\n                \r\n                    ',
#   ' 시크노블\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '3,600원',
#   4,
#   4,
#   'BL'],
#  [24,
#   '[eBook]   [BL] 스위티, 스위티, 스위티(Sweetie, Sweetie, Sweetie)(EPUB, 완결) \r\n            \r\n            ',
#   '\n담적단 저  \r\n                \r\n                \r\n                    ',
#   ' 러스트\r\n                \r\n                    ',
#   ' 2022년 09월\r\n                 \r\n            ',
#   '3,300원',
#   4,
#   4,
#   'BL'],
#  [25,
#   '[eBook]   [BL] 다시(EPUB) \r\n            \r\n            ',
#   '\n라임나무 저  \r\n                \r\n                \r\n                    ',
#   ' 비욘드\r\n                \r\n                    ',
#   ' 2022년 06월\r\n                 \r\n            ',
#   '3,700원',
#   4,
#   4,
#   'BL'],
#  [26,
#   '[eBook]   [BL] 뜬장 위의 개(EPUB, 완결) \r\n            \r\n            ',
#   '\n차옌 저  \r\n                \r\n                \r\n                    ',
#   ' 비욘드\r\n                \r\n                    ',
#   ' 2022년 01월\r\n                 \r\n            ',
#   '5,100원',
#   4,
#   4,
#   'BL'],
#  [27,
#   '[eBook]   [BL] 달달(EPUB) \r\n            \r\n            ',
#   '\nMaRO 저  \r\n                \r\n                \r\n                    ',
#   ' 모드\r\n                \r\n                    ',
#   ' 2021년 08월\r\n                 \r\n            ',
#   '4,000원',
#   4,
#   4,
#   'BL'],
#  [28,
#   '[eBook]   [BL] 낮과 밤(EPUB) \r\n            \r\n            ',
#   '\n나나코 저  \r\n                \r\n                \r\n                    ',
#   ' 블러쉬\r\n                \r\n                    ',
#   ' 2021년 01월\r\n                 \r\n            ',
#   '3,500원',
#   4,
#   4,
#   'BL'],
#  [29,
#   '[eBook]   [BL] 엠프티(Empty)(EPUB, 완결) \r\n            \r\n            ',
#   '\n라돌체 저  \r\n                \r\n                \r\n                    ',
#   ' 블러쉬\r\n                \r\n                    ',
#   ' 2019년 03월\r\n                 \r\n            ',
#   '2,800원',
#   4,
#   4,
#   'BL'],
#  [30,
#   '[eBook]   [BL] 평행세계 (The Parallel World)(EPUB) \r\n            \r\n            ',
#   '\nRyumati 저  \r\n                \r\n                \r\n                    ',
#   ' 블러쉬\r\n                \r\n                    ',
#   ' 2016년 10월\r\n                 \r\n            ',
#   '3,000원',
#   3,
#   3,
#   'BL'],
#  [31,
#   '[eBook]   [BL] 망한 세상에서 살아남기(EPUB) \r\n            \r\n            ',
#   '\n맛좋은감자탕 저  \r\n                \r\n                \r\n                    ',
#   ' BLYNUE 블리뉴\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,500원',
#   0,
#   0,
#   'BL'],
#  [32,
#   '[eBook]   [BL] 세컨드 러브 송(Second love song)(EPUB) \r\n            \r\n            ',
#   '\n코르테즈 저  \r\n                \r\n                \r\n                    ',
#   ' MANZ’\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,300원',
#   0,
#   0,
#   'BL'],
#  [33,
#   '[eBook]   [루비] 투명한 사랑의 그릇 (한정판)(COMIC) \r\n            \r\n            ',
#   '\nhitomi 글그림  \r\n                \r\n                \r\n                    ',
#   ' 현대지능개발사\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,780원',
#   4,
#   4,
#   'BL'],
#  [34,
#   '[eBook]   [BL] 알파는 알파를 갈망한다(EPUB) \r\n            \r\n            ',
#   '\n네롤리 저  \r\n                \r\n                \r\n                    ',
#   ' 골드핑거\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '1,000원',
#   0,
#   0,
#   'BL'],
#  [35,
#   '[eBook]   [BL] 오만한 아우를 위한 교습(EPUB) \r\n            \r\n            ',
#   '\nbtlz 저  \r\n                \r\n                \r\n                    ',
#   ' 디퍼노블\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '900원',
#   0,
#   0,
#   'BL'],
#  [36,
#   '[eBook]   [BL] 정사원서 (情絲怨緖)(EPUB, 완결) \r\n            \r\n            ',
#   '\n버터앙팡 저  \r\n                \r\n                \r\n                    ',
#   ' BLYNUE 블리뉴\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,400원',
#   5,
#   5,
#   'BL'],
#  [37,
#   '[eBook]   오늘도 첫날밤에 도전 중입니다(COMIC) \r\n            \r\n            ',
#   '\n키다 삿츠 글그림  \r\n                \r\n                \r\n                    ',
#   ' 감각\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,780원',
#   4,
#   4,
#   'BL'],
#  [38,
#   '[eBook]   [BL] 구멍 신부(EPUB) \r\n            \r\n            ',
#   '\n국산파이어팅커BL 저  \r\n                \r\n                \r\n                    ',
#   ' 희우\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '2,700원',
#   5,
#   5,
#   'BL'],
#  [39,
#   '[eBook]   [허니B] 변태 같은 그 녀석은 사랑받고 싶다!\n',
#   '\ntakatu aki 저  \r\n                \r\n                \r\n                    ',
#   ' GTENT\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '500원',
#   0,
#   0,
#   'BL'],
#  [40,
#   '[eBook]   [BL] 차사태신전(EPUB) \r\n            \r\n            ',
#   '\n급한 저  \r\n                \r\n                \r\n                    ',
#   ' BLYNUE 블리뉴\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '3,400원',
#   4,
#   4,
#   'BL'],
#  [41,
#   '[eBook]   [BL] 조교 실격(EPUB, 완결) \r\n            \r\n            ',
#   '\n쇼베 저  \r\n                \r\n                \r\n                    ',
#   ' 시크노블\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '3,500원',
#   4,
#   4,
#   'BL'],
#  [42,
#   '[eBook]   [BL] 풀 블룸(Full bloom)(EPUB, 완결) \r\n            \r\n            ',
#   '\n구부 저  \r\n                \r\n                \r\n                    ',
#   ' 시크노블\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '3,300원',
#   4,
#   4,
#   'BL'],
#  [43,
#   '[eBook]   [BL] 담뱃재(EPUB) \r\n            \r\n            ',
#   '\n원리드 저  \r\n                \r\n                \r\n                    ',
#   ' BLYNUE 블리뉴\r\n                \r\n                    ',
#   ' 2022년 10월\r\n                 \r\n            ',
#   '3,900원',
#   4,
#   4,
#   'BL'],
#  [44,
#   '[eBook]   [BL] 오류탐구영역(EPUB, 완결) \r\n            \r\n            ',
#   '\n망고곰 저  \r\n                \r\n                \r\n                    ',
#   ' 북극여우\r\n                \r\n                    ',
#   ' 2022년 10월\r\n                 \r\n            ',
#   '4,500원',
#   4,
#   4,
#   'BL'],
#  [45,
#   '[eBook]   [BL] 탐색전(EPUB, 완결) \r\n            \r\n            ',
#   '\n오후네시육분 저  \r\n                \r\n                \r\n                    ',
#   ' 시크노블\r\n                \r\n                    ',
#   ' 2017년 03월\r\n                 \r\n            ',
#   '3,000원',
#   4,
#   4,
#   'BL'],
#  [46,
#   '[eBook]   [BL] DASH(EPUB, 완결) \r\n            \r\n            ',
#   '\n이젠(ijen) 저  \r\n                \r\n                \r\n                    ',
#   ' W-Beast\r\n                \r\n                    ',
#   ' 2022년 01월\r\n                 \r\n            ',
#   '4,400원',
#   4,
#   4,
#   'BL'],
#  [47,
#   '[eBook]   라라의 결혼\n',
#   '\n타메코우 글그림  \r\n                \r\n                \r\n                    ',
#   ' 블랑코믹스\r\n                \r\n                    ',
#   ' 2020년 02월\r\n                 \r\n            ',
#   '3,780원',
#   4,
#   4,
#   'BL'],
#  [48,
#   '[eBook]   [BL] 비밀한 연애(EPUB, 완결, eBook/크레마 3만원 이상 구매 시 디즈니 북램프/윤동주 팔각머그 택1 증정 (포인트차감, 한정수량)) \r\n            \r\n            ',
#   '\n일면식 저  \r\n                \r\n                \r\n                    ',
#   ' 시크노블\r\n                \r\n                    ',
#   ' 2020년 05월\r\n                 \r\n            ',
#   '4,000원',
#   4,
#   4,
#   'BL'],
#  [49,
#   '[eBook]   [세트] [BL] 선생님, 선생님 (외전 포함) (총2권/완결)\n',
#   '\n재떨이 저  \r\n                \r\n                \r\n                    ',
#   ' BLYNUE 블리뉴\r\n                \r\n                    ',
#   ' 2020년 03월\r\n                 \r\n            ',
#   '4,000원',
#   4,
#   4,
#   'BL'],
#  [50,
#   '[eBook]   [대여] 첫사랑이 이를 드러내다(20% 쿠폰 받아 구입하세요!, COMIC) \r\n            \r\n            ',
#   '\nEisuji 글그림  \r\n                \r\n                \r\n                    ',
#   ' 현대지능개발사\r\n                \r\n                    ',
#   ' 2019년 08월\r\n                 \r\n            ',
#   '1,440원',
#   4,
#   5,
#   'BL'],
#  [51,
#   '[eBook]   [슈크림] [BL] 내 버진은 안 팔아!(COMIC, 완결) \r\n            \r\n            ',
#   '\n쿠오 츠나시 글그림  \r\n                \r\n                \r\n                    ',
#   ' 슈크림코믹스\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '4,320원',
#   0,
#   0,
#   'BL'],
#  [52,
#   '[eBook]   [BL] 슈가 크러시 러브(Sugar Crush Love)(EPUB) \r\n            \r\n            ',
#   '\n골햄 저  \r\n                \r\n                \r\n                    ',
#   ' 문라이트북스\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '3,600원',
#   5,
#   5,
#   'BL'],
#  [53,
#   '[eBook]   [BL] 애일(愛日)(EPUB) \r\n            \r\n            ',
#   '\n씹스틱 저  \r\n                \r\n                \r\n                    ',
#   ' 쇼트랙\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '1,300원',
#   0,
#   0,
#   'BL'],
#  [54,
#   '[eBook]   [BL] 쌍둥이 형들 사이에 끼어서(EPUB) \r\n            \r\n            ',
#   '\n초코치치 저  \r\n                \r\n                \r\n                    ',
#   ' 플레이룸\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '1,100원',
#   0,
#   0,
#   'BL'],
#  [55,
#   '[eBook]   [라르고]미드나잇 문 (한정판)(COMIC) \r\n            \r\n            ',
#   '\n이케이즈미 글그림  \r\n                \r\n                \r\n                    ',
#   ' (주)조은세상\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '4,320원',
#   0,
#   0,
#   'BL'],
#  [56,
#   '[eBook]   [BL] 광공의 솜뭉치로 빙의함(EPUB, 완결) \r\n            \r\n            ',
#   '\n김덕팔 저  \r\n                \r\n                \r\n                    ',
#   ' 파란달\r\n                \r\n                    ',
#   ' 2022년 03월\r\n                 \r\n            ',
#   '3,330원',
#   4,
#   4,
#   'BL'],
#  [57,
#   '[eBook]   [BL] 그놈이 그놈이다(EPUB) \r\n            \r\n            ',
#   '\n차선 저  \r\n                \r\n                \r\n                    ',
#   ' BLYNUE 블리뉴\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,700원',
#   5,
#   5,
#   'BL'],
#  [58,
#   '[eBook]   [시안] 넘겨진 개, 넘기는 밤\n',
#   '\n노바라 아이코 글그림  \r\n                \r\n                \r\n                    ',
#   ' 시안\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,780원',
#   4,
#   4,
#   'BL'],
#  [59,
#   '[eBook]   [BL] 분홍색 구멍(EPUB) \r\n            \r\n            ',
#   '\n파배씨 저  \r\n                \r\n                \r\n                    ',
#   ' 골드핑거\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '900원',
#   0,
#   0,
#   'BL'],
#  [60,
#   '[eBook]   [BL] 산 속의 캠핑 : 한뼘 BL 컬렉션 1237(EPUB) \r\n            \r\n            ',
#   '\n호두시리얼 저  \r\n                \r\n                \r\n                    ',
#   ' 젤리빈\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '900원',
#   0,
#   0,
#   'BL'],
#  [61,
#   '[eBook]   [대여] 오늘도 첫날밤에 도전 중입니다(COMIC) \r\n            \r\n            ',
#   '\n키다 삿츠 글그림  \r\n                \r\n                \r\n                    ',
#   ' 감각\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '1,680원',
#   4,
#   4,
#   'BL'],
#  [62,
#   '[eBook]   [크림툰] 오메가의 비밀은 호텔 안에\n',
#   '\n사라 사아야 글그림  \r\n                \r\n                \r\n                    ',
#   ' 프라이데이\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,780원',
#   4,
#   4,
#   'BL'],
#  [63,
#   '[eBook]   [라르고] 별과 고슴도치(COMIC) \r\n            \r\n            ',
#   '\n나고 나유타 글그림  \r\n                \r\n                \r\n                    ',
#   ' (주)조은세상\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '3,780원',
#   4,
#   4,
#   'BL'],
#  [64,
#   '[eBook]   [BL] 다정도 병인 양하여(EPUB) \r\n            \r\n            ',
#   '\nFensterrahmen 저  \r\n                \r\n                \r\n                    ',
#   ' B cafe\r\n                \r\n                    ',
#   ' 2017년 08월\r\n                 \r\n            ',
#   '3,000원',
#   4,
#   4,
#   'BL'],
#  [65,
#   '[eBook]   [BL] 피는 물보다 연하다(EPUB) \r\n            \r\n            ',
#   '\n삼루 저  \r\n                \r\n                \r\n                    ',
#   ' 트리스트\r\n                \r\n                    ',
# ...
#   '\n애덤 파이필드 저/김희정 역  \r\n                \r\n                \r\n                    ',
#   ' 부키\r\n                \r\n                    ',
#   ' 2017년 12월\r\n                 \r\n            ',
#   '13,000원',
#   0,
#   0,
#   '사회 정치'],
#  [65,
#   '[eBook]   새로 쓴 원숭이도 이해하는 자본론 : 세상에서 가장 쉬운 임승수의 마르크스 자본론 강의(EPUB) \r\n            \r\n            ',
#   '\n임승수 저  \r\n                \r\n                \r\n                    ',
#   ' 시대의창\r\n                \r\n                    ',
#   ' 2017년 08월\r\n                 \r\n            ',
#   '9,000원',
#   4,
#   4,
#   '사회 정치'],
#  [66,
#   '[eBook]   당신이 계속 불편하면 좋겠습니다(EPUB) \r\n            \r\n            ',
#   '\n홍승은 저  \r\n                \r\n                \r\n                    ',
#   ' 동녘\r\n                \r\n                    ',
#   ' 2017년 07월\r\n                 \r\n            ',
#   '9,450원',
#   5,
#   5,
#   '사회 정치'],
#  [67,
#   '[eBook]   아주 친밀한 폭력 : 여성주의와 가정 폭력 (EPUB) \r\n            \r\n            ',
#   '\n정희진 저  \r\n                \r\n                \r\n                    ',
#   ' 교양인\r\n                \r\n                    ',
#   ' 2017년 06월\r\n                 \r\n            ',
#   '10,500원',
#   5,
#   4,
#   '사회 정치'],
#  [68,
#   '[eBook]   형사 사례중심 Self 항고장(EPUB) \r\n            \r\n            ',
#   '\n장태동 저  \r\n                \r\n                \r\n                    ',
#   ' 남산\r\n                \r\n                    ',
#   ' 2017년 05월\r\n                 \r\n            ',
#   '10,000원',
#   0,
#   0,
#   '사회 정치'],
#  [69,
#   '[eBook]   형사 사례중심  Self 재정신청서(EPUB) \r\n            \r\n            ',
#   '\n장태동 저  \r\n                \r\n                \r\n                    ',
#   ' 남산\r\n                \r\n                    ',
#   ' 2017년 05월\r\n                 \r\n            ',
#   '10,000원',
#   0,
#   0,
#   '사회 정치'],
#  [70,
#   '[eBook]   폭정 : 20세기의 스무 가지 교훈(EPUB) \r\n            \r\n            ',
#   '\n티머시 스나이더 저/조행복 역  \r\n                \r\n                \r\n                    ',
#   ' 열린책들\r\n                \r\n                    ',
#   ' 2017년 04월\r\n                 \r\n            ',
#   '8,000원',
#   4,
#   4,
#   '사회 정치'],
#  [71,
#   '[eBook]   국가란 무엇인가(EPUB) \r\n            \r\n            ',
#   '\n유시민 저  \r\n                \r\n                \r\n                    ',
#   ' 돌베개\r\n                \r\n                    ',
#   ' 2017년 01월\r\n                 \r\n            ',
#   '10,500원',
#   4,
#   4,
#   '사회 정치'],
#  [72,
#   '[eBook]   헨리 키신저의 중국 이야기(EPUB) \r\n            \r\n            ',
#   '\n헨리 키신저 저/권기대 역  \r\n                \r\n                \r\n                    ',
#   ' 민음사\r\n                \r\n                    ',
#   ' 2016년 09월\r\n                 \r\n            ',
#   '17,500원',
#   5,
#   5,
#   '사회 정치'],
#  [73,
#   '[eBook]   나무 수업(EPUB) \r\n            \r\n            ',
#   '\n페터 볼레벤 저 / 장혜경 역 저  \r\n                \r\n                \r\n                    ',
#   ' 위즈덤하우스\r\n                \r\n                    ',
#   ' 2016년 03월\r\n                 \r\n            ',
#   '8,300원',
#   0,
#   0,
#   '사회 정치'],
#  [74,
#   '[eBook]   지속 가능한 발전의 시대(EPUB) \r\n            \r\n            ',
#   '\n제프리 D. 삭스 저  \r\n                \r\n                \r\n                    ',
#   ' 21세기북스\r\n                \r\n                    ',
#   ' 2015년 10월\r\n                 \r\n            ',
#   '33,600원',
#   0,
#   0,
#   '사회 정치'],
#  [75,
#   '[eBook]   후불제 민주주의 : 유시민의 헌법 에세이(EPUB) \r\n            \r\n            ',
#   '\n유시민 저  \r\n                \r\n                \r\n                    ',
#   ' 돌베개\r\n                \r\n                    ',
#   ' 2013년 02월\r\n                 \r\n            ',
#   '9,800원',
#   4,
#   4,
#   '사회 정치'],
#  [76,
#   '[eBook]   경찰관속으로 : 언니에게 부치는 편지(EPUB) \r\n            \r\n            ',
#   '\n원도 저  \r\n                \r\n                \r\n                    ',
#   ' 이후진프레스\r\n                \r\n                    ',
#   ' 2022년 06월\r\n                 \r\n            ',
#   '9,800원',
#   0,
#   0,
#   '사회 정치'],
#  [77,
#   '[eBook]   우리는 왜 서로를 미워하는가 : 편 가르기 시대 휘둘리지 않는 유권자를 위한 정당정치 안내서(EPUB) \r\n            \r\n            ',
#   '\n에즈라 클라인 저/황성연 역  \r\n                \r\n                \r\n                    ',
#   ' 윌북(willbook)\r\n                \r\n                    ',
#   ' 2022년 06월\r\n                 \r\n            ',
#   '13,000원',
#   0,
#   0,
#   '사회 정치'],
#  [78,
#   '[eBook]   인공지능, 법에게 미래를 묻다 : 로봇 기술 활용에 앞서 알아야 할 법 제도 이야기(EPUB) \r\n            \r\n            ',
#   '\n정상조 저  \r\n                \r\n                \r\n                    ',
#   ' 사회평론\r\n                \r\n                    ',
#   ' 2022년 05월\r\n                 \r\n            ',
#   '9,000원',
#   0,
#   0,
#   '사회 정치'],
#  [79,
#   '[eBook]   반란의 매춘부 : 성노동자 권리를 위한 투쟁  (EPUB) \r\n            \r\n            ',
#   '\n몰리 스미스,주노 맥 저/이명훈 역  \r\n                \r\n                \r\n                    ',
#   ' 오월의봄\r\n                \r\n                    ',
#   ' 2022년 06월\r\n                 \r\n            ',
#   '15,400원',
#   0,
#   0,
#   '사회 정치'],
#  [80,
#   '[eBook]   당신의 쓰레기는 재활용되지 않았다 : 재활용 시스템의 모순과 불평등, 그리고 친환경이라는 거짓말(PDF) \r\n            \r\n            ',
#   '\n미카엘라 르 뫼르 저/구영옥 역  \r\n                \r\n                \r\n                    ',
#   ' 풀빛\r\n                \r\n                    ',
#   ' 2022년 06월\r\n                 \r\n            ',
#   '10,360원',
#   0,
#   0,
#   '사회 정치'],
#  [81,
#   '[eBook]   대안학교를 설립하는 노하우(PDF) \r\n            \r\n            ',
#   '\n이관준 저  \r\n                \r\n                \r\n                    ',
#   ' 유페이퍼\r\n                \r\n                    ',
#   ' 2022년 04월\r\n                 \r\n            ',
#   '5,600원',
#   0,
#   0,
#   '사회 정치'],
#  [82,
#   '[eBook]   불평등한 선진국 : 대한민국의 불평등을 통계로 보다(EPUB) \r\n            \r\n            ',
#   '\n박재용 저  \r\n                \r\n                \r\n                    ',
#   ' 북루덴스\r\n                \r\n                    ',
#   ' 2022년 04월\r\n                 \r\n            ',
#   '13,500원',
#   0,
#   0,
#   '사회 정치'],
#  [83,
#   '[eBook]   윤석열 파워엘리트 263人(EPUB) \r\n            \r\n            ',
#   '\n신동아 편집실 저  \r\n                \r\n                \r\n                    ',
#   ' 동아일보사\r\n                \r\n                    ',
#   ' 2022년 04월\r\n                 \r\n            ',
#   '5,000원',
#   0,
#   0,
#   '사회 정치'],
#  [84,
#   '[eBook]   우리 안의 파시즘 2.0 : 내 편만 옳은 사회에서 민주주의는 가능한가?(EPUB) \r\n            \r\n            ',
#   '\n김진호,정희진,이진우,배묘정,이철승,조영한,김내훈,박상훈 저/이욱연,우찬제 편 외 1명  \r\n                \r\n                \r\n                \r\n                    \n\n정보 더 보기/감추기\n\n\n\n\n김진호\n정희진\n이진우\n배묘정\n이철승\n조영한\n김내훈\n박상훈\n이욱연\n우찬제\n임지현\n\n\n\n\r\n                  \r\n                \r\n                    ',
#   ' 휴머니스트\r\n                \r\n                    ',
#   ' 2022년 02월\r\n                 \r\n            ',
#   '11,200원',
#   0,
#   0,
#   '사회 정치'],
#  [85,
#   '[eBook]   AI는 차별을 인간에게서 배운다 : 인간과 기술의 공존을 위해 다시 세우는 정의(EPUB) \r\n            \r\n            ',
#   '\n고학수 저  \r\n                \r\n                \r\n                    ',
#   ' 21세기북스\r\n                \r\n                    ',
#   ' 2022년 02월\r\n                 \r\n            ',
#   '12,800원',
#   0,
#   0,
#   '사회 정치'],
#  [86,
#   '[eBook]   사람입니다, 고객님 : 콜센터의 인류학(EPUB) \r\n            \r\n            ',
#   '\n김관욱 저  \r\n                \r\n                \r\n                    ',
#   ' 창비\r\n                \r\n                    ',
#   ' 2022년 01월\r\n                 \r\n            ',
#   '14,000원',
#   5,
#   5,
#   '사회 정치'],
#  [87,
#   '[eBook]   커리어 그리고 가정 : 평등을 향한 여성들의 기나긴 여정(EPUB) \r\n            \r\n            ',
#   '\n클라우디아 골딘 저/김승진 역  \r\n                \r\n                \r\n                    ',
#   ' 생각의힘\r\n                \r\n                    ',
#   ' 2022년 01월\r\n                 \r\n            ',
#   '19,800원',
#   0,
#   0,
#   '사회 정치'],
#  [88,
#   '[eBook]   특수교사 119 : 아무도 알려주지 않은 특수학급 운영법(EPUB) \r\n            \r\n            ',
#   '\n원재연 저  \r\n                \r\n                \r\n                    ',
#   ' 에듀니티\r\n                \r\n                    ',
#   ' 2021년 05월\r\n                 \r\n            ',
#   '13,600원',
#   0,
#   0,
#   '사회 정치'],
#  [89,
#   '[eBook]   종교단체(종교인)을 위한 개인정보보호(PDF) \r\n            \r\n            ',
#   '\n원성만 임창빈 김민정 강지현 이지연 저  \r\n                \r\n                \r\n                    ',
#   ' 도서출판 온누리\r\n                \r\n                    ',
#   ' 2021년 05월\r\n                 \r\n            ',
#   '1,000원',
#   0,
#   0,
#   '사회 정치'],
#  [90,
#   '[eBook]   능력주의와 불평등 : 능력에 따른 차별은 공정하다는 믿음에 대하여(EPUB) \r\n            \r\n            ',
#   '\n홍세화,박권일,이경숙,공현,이유림,정용주,채효정,김혜진,김혜경,문종완 저  \r\n                \r\n                \r\n                    ',
#   ' 교육공동체벗\r\n                \r\n                    ',
#   ' 2021년 02월\r\n                 \r\n            ',
#   '9,800원',
#   5,
#   5,
#   '사회 정치'],
#  [91,
#   '[eBook]   엔스케이프 2.9 사용설명서 [인테리어 실무 투시도편](PDF) \r\n            \r\n            ',
#   '\n최주영 저  \r\n                \r\n                \r\n                    ',
#   ' 유페이퍼\r\n                \r\n                    ',
#   ' 2021년 11월\r\n                 \r\n            ',
#   '19,500원',
#   0,
#   0,
#   '사회 정치'],
#  [92,
#   '[eBook]   사회복지 프로그램 개발과 평가 (2판)(PDF) \r\n            \r\n            ',
#   '\n이봉주,김기덕,신원우 공저  \r\n                \r\n                \r\n                    ',
#   ' 신정\r\n                \r\n                    ',
#   ' 2021년 03월\r\n                 \r\n            ',
#   '18,000원',
#   0,
#   0,
#   '사회 정치'],
#  [93,
#   '[eBook]   억울한 부당해고 길라잡이 (중요 판결문 모음집)(PDF) \r\n            \r\n            ',
#   '\n법률나무 저  \r\n                \r\n                \r\n                    ',
#   ' 미디어 북\r\n                \r\n                    ',
#   ' 2021년 01월\r\n                 \r\n            ',
#   '39,000원',
#   0,
#   0,
#   '사회 정치'],
#  [94,
#   '[eBook]   아주 오래된 유죄 : 그러나 포기하지 않은 여성을 위한 변론(EPUB) \r\n            \r\n            ',
#   '\n김수정 저  \r\n                \r\n                \r\n                    ',
#   ' 한겨레출판\r\n                \r\n                    ',
#   ' 2020년 12월\r\n                 \r\n            ',
#   '10,500원',
#   0,
#   0,
#   '사회 정치'],
#  [95,
#   '[eBook]   김삼연 변호사의 [함께 읽는 근로기준법](EPUB) \r\n            \r\n            ',
#   '\n변호사 김삼연 저  \r\n                \r\n                \r\n                    ',
#   ' 시아북스\r\n                \r\n                    ',
#   ' 2020년 07월\r\n                 \r\n            ',
#   '5,900원',
#   0,
#   0,
#   '사회 정치'],
#  [1,
#   '[eBook]   악인론 : 닥치고 성공해 누구에게도 지배받지 않는 삶 (EPUB) \r\n            \r\n            ',
#   '\n손수현 저  \r\n                \r\n                \r\n                    ',
#   ' 다산북스\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '12,900원',
#   0,
#   0,
#   '자기계발'],
#  [2,
#   '[eBook]   1퍼센트 부자의 법칙 : 반드시 성공하는 일천 번의 법칙(EPUB) \r\n            \r\n            ',
#   '\n사이토 히토리 저/김진아 역  \r\n                \r\n                \r\n                    ',
#   ' 나비스쿨(NAVI SCHOOL)\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '12,000원',
#   4,
#   4,
#   '자기계발'],
#  [3,
#   '[eBook]   김미경의 마흔 수업(EPUB) \r\n            \r\n            ',
#   '\n김미경 저  \r\n                \r\n                \r\n                    ',
#   ' 어웨이크북스\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '12,600원',
#   0,
#   0,
#   '자기계발'],
#  [4,
#   '[eBook]   원씽 : 복잡한 세상을 이기는 단순함의 힘(EPUB) \r\n            \r\n            ',
#   '\n제이 파파산,게리 켈러 저/구세희 역  \r\n                \r\n                \r\n                    ',
#   ' 비즈니스북스\r\n                \r\n                    ',
#   ' 2013년 08월\r\n                 \r\n            ',
#   '10,000원',
#   4,
#   4,
#   '자기계발'],
#  [5,
#   '[eBook]   무조건 합격하는 암기의 기술 : 26살 9개월 만에 사법시험을 패스한 이윤규 변호사의 책 한 권 통째로 씹어먹는 공부법 (EPUB) \r\n            \r\n            ',
#   '\n이윤규 저  \r\n                \r\n                \r\n                    ',
#   ' 더퀘스트\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '15,040원',
#   0,
#   0,
#   '자기계발'],
#  [6,
#   '[eBook]   역행자 : 돈·시간·운명으로부터 완전한 자유를 얻는 7단계 인생 공략집(EPUB) \r\n            \r\n            ',
#   '\n자청 저  \r\n                \r\n                \r\n                    ',
#   ' 웅진지식하우스\r\n                \r\n                    ',
#   ' 2022년 05월\r\n                 \r\n            ',
#   '11,070원',
#   4,
#   4,
#   '자기계발'],
#  [7,
#   '[eBook]   모든 것이 괜찮아지는 기술 : 불안, 분노, 스트레스로부터 나를 지키는 심리 기술(EPUB) \r\n            \r\n            ',
#   '\n데런 브라운 저/김정희 역  \r\n                \r\n                \r\n                    ',
#   ' 너를위한\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '12,300원',
#   0,
#   0,
#   '자기계발'],
#  [8,
#   '[eBook]   지무비의 유튜브 엑시트 : 무일푼 취준생을 월수입 억대 크리에이터로 만든 실전 노하우 (EPUB) \r\n            \r\n            ',
#   '\n지무비(나현갑) 저  \r\n                \r\n                \r\n                    ',
#   ' 21세기북스\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '15,840원',
#   0,
#   0,
#   '자기계발'],
#  [9,
#   '[eBook]   [단독] 운을 벌어야 돈이 벌린다(단독 선출간!, EPUB) \r\n            \r\n            ',
#   '\n이정재 저  \r\n                \r\n                \r\n                    ',
#   ' 부커\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '12,750원',
#   4,
#   4,
#   '자기계발'],
#  [10,
#   '[eBook]   데일 카네기 인간관계론(EPUB)-tvN 요즘책방 소개도서 27 \r\n            \r\n            ',
#   '\n데일 카네기 저/임상훈 역  \r\n                \r\n                \r\n                    ',
#   ' 현대지성\r\n                \r\n                    ',
#   ' 2019년 10월\r\n                 \r\n            ',
#   '5,500원',
#   4,
#   4,
#   '자기계발'],
#  [11,
#   '[eBook]   일생에 단 한번은 독기를 품어라(EPUB) \r\n            \r\n            ',
#   '\n권민창 저  \r\n                \r\n                \r\n                    ',
#   ' 마인드셋(Mindset)\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '11,000원',
#   0,
#   0,
#   '자기계발'],
#  [12,
#   '[eBook]   신경 끄기 연습 : 걱정, 초조, 두려움을 뛰어넘는 61가지 심리 기술(EPUB) \r\n            \r\n            ',
#   '\n나이토 요시히토 저/김한나 역  \r\n                \r\n                \r\n                    ',
#   ' 유노책주\r\n                \r\n                    ',
#   ' 2023년 01월\r\n                 \r\n            ',
#   '12,000원',
#   0,
#   0,
#   '자기계발'],
#  [13,
#   '[eBook]   자소서 바이블 2.0 : 한 줄만 읽어도 합격하는 자소서(EPUB) \r\n            \r\n            ',
#   '\n면접왕 이형 저  \r\n                \r\n                \r\n                    ',
#   ' 얼라이브북스(alivebooks)\r\n                \r\n                    ',
#   ' 2022년 09월\r\n                 \r\n            ',
#   '16,830원',
#   5,
#   5,
#   '자기계발'],
#  [14,
#   '[eBook]   콰이어트 모닝 : 생각이 현실이 되는 고요한 시간의 힘(EPUB) \r\n            \r\n            ',
#   '\n추현호 저  \r\n                \r\n                \r\n                    ',
#   ' 클레이하우스\r\n                \r\n                    ',
#   ' 2023년 02월\r\n                 \r\n            ',
#   '11,500원',
#   0,
#   0,
#   '자기계발'],
#  [15,
#   '[eBook]   나는 하루 5분만 바꾸기로 했다(EPUB) \r\n            \r\n            ',
#   '\n옥민송 저  \r\n                \r\n                \r\n                    ',
#   ' 콘택트\r\n                \r\n                    ',
#   ' 2022년 12월\r\n                 \r\n            ',
#   '11,700원',
#   0,
#   0,
#   '자기계발'],
#  [16,
#   '[eBook]   [대여] 역행자 : 돈·시간·운명으로부터 완전한 자유를 얻는 7단계 인생 공략집(30% 대여 할인 쿠폰 받아 구입하세요!, EPUB) \r\n            \r\n            ',
#   '\n자청 저  \r\n                \r\n                \r\n                    ',
#   ' 웅진지식하우스\r\n                \r\n                    ',
#   ' 2022년 05월\r\n                 \r\n            ',
#   '6,150원',
#   4,
#   4,
#   '자기계발'],
#  [17,
#   '[eBook]   서울 자가에 대기업 다니는 김 부장 이야기 3 송 과장 편(EPUB) \r\n            \r\n            ',
#   '\n송희구 저  \r\n                \r\n                \r\n                    ',
#   ' 서삼독\r\n                \r\n                    ',
#   ' 2021년 11월\r\n                 \r\n            ',
#   '12,000원',
#   4,
#   5,
#   '자기계발'],
#  [18,
#   '[eBook]   나는 무조건 합격하는 공부만 한다 : 26살, 9개월 만에 사법시험을 패스한 이윤규 변호사의 패턴 공부법(EPUB) \r\n            \r\n            ',
#   '\n이윤규 저  \r\n                \r\n                \r\n                    ',
#   ' 비즈니스북스\r\n                \r\n                    ',
#   ' 2019년 12월\r\n                 \r\n            ',
#   '10,500원',
#   4,
#   4,
#   '자기계발'],
#  ...]

# %%
df = pd.DataFrame(bookss, columns=['yes24_rank','title','yes24_writer', 'yes24_company','yes24_date','yes24_price' ,'yes24_star_content','yes24_star_edit','yes24_gener'])

df['yes24_date'] = df['yes24_date'].str.replace(pat=r'[^A-Za-z0-9가-힣]', repl=r' ', regex=True)

df['yes24_writer']=df['yes24_writer'].str.replace(pat=r'[^A-Za-z0-9가-힣]', repl=r' ', regex=True)
df['title'] = df['title'].str.replace(pat=r'[^A-Za-z0-9가-힣]', repl=r' ', regex=True)
for i in ['eBook','EPUB','완결','COMIC','PDF']:
    df['title'] = df['title'].str.replace(pat=i, repl=r' ', regex=True)


df['yes24_company'] = df['yes24_company'].str.replace(pat=r'[^A-Za-z0-9가-힣]', repl=r' ', regex=True)


func = lambda x: name_mapping.get(x, x)


df['sm_gener'] = df.yes24_gener.map(func)

# %%
df
# Out:
#       yes24_rank                                              title  \
# 0              1           난잡하고 불순한
# 1              2        조건  만남  삽화본                             ...
# 2              3                      세트  오빠 손은 약손  외전 포함   총2권
# 3              4           토굴 공주
# 4              5                       세트  오  담에 핀 꽃  개정판   총3권
# ...          ...                                                ...
# 2117          16        How Not to Run for Class President      ...
# 2118          17        The Year of Magical Thinking            ...
# 2119          18             Wonder
# 2120          19        A to Z Mysteries   The Deadly Dungeon   ...
# 2121          20        Princess Ellie s Holiday Adventure      ...
#
#                                            yes24_writer  \
# 0      얀yan 저                                       ...
# 1      문정민 저                                        ...
# 2      금나래 저                                        ...
# 3      함초롱 저                                        ...
# 4      박영 저                                         ...
# ...                                                 ...
# 2117   James Fallon 저                               ...
# 2118   Joan Didion 저                                ...
# 2119   R  J  Palacio 저                              ...
# 2120   Ron Roy 저                                    ...
# 2121   Diana Kimpton 저                              ...
#
#                                           yes24_company  \
# 0        해피북스투유
# 1            로아
# 2            텐북
# 3          제로노블
# 4           플로린
# ...                                                 ...
# 2117   Penguin Publishing Group                     ...
# 2118   Knopf Doubleday Publishing Group             ...
# 2119   Random House Children s Books                ...
# 2120   Random House Children s Books                ...
# 2121   Usborne Publishing Ltd                       ...
#
#                                        yes24_date yes24_price  \
# 0      2023년 02월                                       3,330원
# 1      2021년 05월                                       3,000원
# 2      2021년 05월                                       4,200원
# 3      2022년 12월                                       3,800원
# 4      2023년 02월                                       9,450원
# ...                                           ...         ...
# 2117   2013년 10월                                       6,000원
# 2118   2007년 02월                                      14,500원
# 2119   2012년 02월                                      20,500원
# 2120   2009년 09월                                       7,000원
# 2121   2005년 05월                                       1,000원
#
#       yes24_star_content  yes24_star_edit    yes24_gener  sm_gener
# 0                      3                3            로맨스        문학
# 1                      4                4            로맨스        문학
# 2                      4                4            로맨스        문학
# 3                      4                4            로맨스        문학
# 4                      0                0            로맨스        문학
# ...                  ...              ...            ...       ...
# 2117                   0                0  크레마 (전자책 단말기)  국외 eBook
# 2118                   5                5  크레마 (전자책 단말기)  국외 eBook
# 2119                   5                5  크레마 (전자책 단말기)  국외 eBook
# 2120                   0                0  크레마 (전자책 단말기)  국외 eBook
# 2121                   4                4  크레마 (전자책 단말기)  국외 eBook
#
# [2122 rows x 10 columns]

# %%
df['yes24_date'] = df['yes24_date'].str.strip()

df['yes24_date'] = df['yes24_date'].str.replace(pat='년 ', repl = '-',regex=True)
df['yes24_date'] = df['yes24_date'].str.replace(pat='월', repl = '',regex=True)
df['yes24_date'] = df['yes24_date'].str.strip()
#df['yes24_date'] = pd.to_datetime(df['yes24_date'],format='%Y-%m')

print(type(df['yes24_date']))
# df['yes24_date'] = pd.to_datetime(df['yes24_date'],format='%Y-%m')
# df['yes24_date'] = pd.to_datetime(df['yes24_date'],format='%Y-%m')

for j in ['원',',']:
    df['yes24_price'] = df['yes24_price'].str.replace(pat=j, repl = '',regex=True)
    df['yes24_price'] = df['yes24_price'].str.strip()
df['yes24_price'] = pd.to_numeric(df['yes24_price'])

df = df[['yes24_rank','title','yes24_writer', 'yes24_company','yes24_date','yes24_price' ,'yes24_star_content','yes24_star_edit','yes24_gener','sm_gener']]

df.to_csv('csv_file\yes24_gener.csv', index= False, encoding= 'utf-8')
# Out:
# <class 'pandas.core.series.Series'>

# %%
df['yes24_date']=pd.to_datetime(df['yes24_date'], format='%Y-%m')

# %%
df
# Out:
#       yes24_rank                                              title  \
# 0              1           난잡하고 불순한
# 1              2        조건  만남  삽화본                             ...
# 2              3                      세트  오빠 손은 약손  외전 포함   총2권
# 3              4           토굴 공주
# 4              5                       세트  오  담에 핀 꽃  개정판   총3권
# ...          ...                                                ...
# 2117          16        How Not to Run for Class President      ...
# 2118          17        The Year of Magical Thinking            ...
# 2119          18             Wonder
# 2120          19        A to Z Mysteries   The Deadly Dungeon   ...
# 2121          20        Princess Ellie s Holiday Adventure      ...
#
#                                            yes24_writer  \
# 0      얀yan 저                                       ...
# 1      문정민 저                                        ...
# 2      금나래 저                                        ...
# 3      함초롱 저                                        ...
# 4      박영 저                                         ...
# ...                                                 ...
# 2117   James Fallon 저                               ...
# 2118   Joan Didion 저                                ...
# 2119   R  J  Palacio 저                              ...
# 2120   Ron Roy 저                                    ...
# 2121   Diana Kimpton 저                              ...
#
#                                           yes24_company yes24_date  \
# 0        해피북스투유                                         2023-02-01
# 1            로아                                         2021-05-01
# 2            텐북                                         2021-05-01
# 3          제로노블                                         2022-12-01
# 4           플로린                                         2023-02-01
# ...                                                 ...        ...
# 2117   Penguin Publishing Group                     ... 2013-10-01
# 2118   Knopf Doubleday Publishing Group             ... 2007-02-01
# 2119   Random House Children s Books                ... 2012-02-01
# 2120   Random House Children s Books                ... 2009-09-01
# 2121   Usborne Publishing Ltd                       ... 2005-05-01
#
#       yes24_price  yes24_star_content  yes24_star_edit    yes24_gener  \
# 0            3330                   3                3            로맨스
# 1            3000                   4                4            로맨스
# 2            4200                   4                4            로맨스
# 3            3800                   4                4            로맨스
# 4            9450                   0                0            로맨스
# ...           ...                 ...              ...            ...
# 2117         6000                   0                0  크레마 (전자책 단말기)
# 2118        14500                   5                5  크레마 (전자책 단말기)
# 2119        20500                   5                5  크레마 (전자책 단말기)
# 2120         7000                   0                0  크레마 (전자책 단말기)
# 2121         1000                   4                4  크레마 (전자책 단말기)
#
#       sm_gener
# 0           문학
# 1           문학
# 2           문학
# 3           문학
# 4           문학
# ...        ...
# 2117  국외 eBook
# 2118  국외 eBook
# 2119  국외 eBook
# 2120  국외 eBook
# 2121  국외 eBook
#
# [2122 rows x 10 columns]
